# %% [markdown]
# # Agitation prediction: Feature extraction
#
# **Author:** Eva Rombouts
# **Date:** 2024-07-19
# **Version:** 1.0
#
# ### Description
# This script performs text preprocessing, topic modeling, and word embedding training on a dataset of care reports. It produces three output files: agitation_train, agitation_valid, and agitation_test, each containing extracted features. These features are prepared for subsequent modeling to predict agitation based on the text data.

# %%
# Environment setup
import os

def check_environment():
    try:
        import google.colab
        return "Google Colab"
    except ImportError:
        return "Local Environment"

env = check_environment()
if env == "Google Colab":
    print("Running in Google Colab")
    # !python -m spacy download nl_core_news_sm -q
    # !pip install -q pyLDAvis
    from google.colab import drive, userdata
    drive.mount('/content/drive')
    os.chdir('/content/drive/My Drive/Colab Notebooks/GenCareAI/scripts/200_agitation_models')
else:
    print("Running in Local Environment")
    # Unable to get it working locally due to persistent ImportError with SciPy's 'triu' function.
    # Therefore, switching to Colab where the environment is pre-configured and works seamlessly.
    # !pip install -q gensim spacy wordcloud pyLDAvis
    # !python -m spacy download nl_core_news_sm -q
# Out:
# Running in Local Environment

# %%
# Libraries for data manipulation 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tqdm import tqdm
tqdm.pandas()

# Visualisation libraries
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis

# NLP & Machine Learning libraries
import spacy
import gensim
from gensim import corpora
from gensim.models import Word2Vec

# Parameters 
num_topics = 10
sample_size = 1000
seed = 6
no_below = 2   # Infrequency limit, minimum number of times the word needs to be in the texts
no_above = 0.5 # Frequency limit, if a word appears in more percent of the texts it will be filtered out.

# Dutch SpaCy model
nlp = spacy.load('nl_core_news_sm', disable=['parser', 'tagger', 'ner'])

# %%
# Load and sample data
df = pd.read_csv('../../data/agitation.csv')
# df = df.sample(sample_size, random_state=seed)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43108 entries, 0 to 43107
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    43108 non-null  object
#  1   label   43108 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 673.7+ KB

# %%
df['label'].value_counts()
# Out:
# label
# 0    38109
# 1     4999
# Name: count, dtype: int64

# %% [markdown]
# ## Text preprocessing

# %%
# Function for text preprocessing: lowercasing, tokenization, lemmatization, stop word removal, and word selection based on part-of-speech
def preprocess_text(text, nlp_model):
    doc = nlp_model(text)
    cleaned_tokens = [token.lemma_.lower() for token in doc if token.is_alpha and not token.is_stop and token.pos_ in ['VERB', 'NOUN', 'ADJ', 'ADV', 'INTJ']]
    return " ".join(cleaned_tokens)

# Apply preprocessing to the dataframe
df['text_clean'] = df['text'].progress_apply(lambda x: preprocess_text(x, nlp))
# Out:
# 100%|██████████| 43108/43108 [01:47<00:00, 402.18it/s]

# %% [markdown]
# ## Splitten in train/test/validatie

# %%
# Split into train/test/validation sets
train_df, temp = train_test_split(df, test_size=0.4, random_state=seed)
valid_df, test_df = train_test_split(temp, test_size=0.5, random_state=seed)

train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25864 entries, 12829 to 31626
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   text        25864 non-null  object
#  1   label       25864 non-null  int64
#  2   text_clean  25864 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 808.2+ KB

# %% [markdown]
# ## Topic modelling

# %%
# Function to plot word clouds for topics
def plot_wordclouds(lda_model, dictionary):
    num_topics = lda_model.num_topics
    cols = 5
    rows = (num_topics // cols) + (num_topics % cols > 0)  # Berekent het aantal rijen

    plt.figure(figsize=(20, 10))  # Aanpassen van de breedte en hoogte van de plot
    for idx in range(num_topics):
        plt.subplot(rows, cols, idx + 1)
        topic_words = dict(lda_model.show_topic(idx, 30))
        cloud = WordCloud(background_color='white').generate_from_frequencies(topic_words)
        plt.imshow(cloud, interpolation='bilinear')
        plt.axis('off')
        plt.title('Topic ' + str(idx+1))

    plt.show()

# %%
# Het model wordt gemaakt obv de trainingset, en vervolgens toegepast op alle data

# Tokenize cleaned texts
tokenized_docs_train = [[token.text for token in nlp(doc)] for doc in train_df['text_clean']]
tokenized_docs_test = [[token.text for token in nlp(doc)] for doc in test_df['text_clean']]
tokenized_docs_valid = [[token.text for token in nlp(doc)] for doc in valid_df['text_clean']]

# %%
# Create a dictionary
dictionary = corpora.Dictionary(tokenized_docs_train)
dictionary.filter_extremes(no_below=no_below, no_above=no_above)

# %%
# Convert documents to a bag-of-words representation
corpus_train = [dictionary.doc2bow(doc) for doc in tokenized_docs_train]
corpus_test = [dictionary.doc2bow(doc) for doc in tokenized_docs_test]
corpus_valid = [dictionary.doc2bow(doc) for doc in tokenized_docs_valid]

# %%
# Train LDA model. The model is trained on the training set only
num_topics = 7
lda_model = gensim.models.LdaMulticore(corpus_train, num_topics=num_topics, id2word=dictionary, passes=10, workers=2, random_state=seed)

lda_model_path = '../../models/agitation/lda_model'
lda_model.save(lda_model_path)
print(f"LDA-model opgeslagen in: {lda_model_path}")
# Out:
# LDA-model opgeslagen in: ../../models/agitation/lda_model

# %%
# Plot topics
plot_wordclouds(lda_model, dictionary)

# %%
# Visualize topics with pyLDAvis
lda_display = gensimvis.prepare(lda_model, corpus_train, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el25656131915728166765378193" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el25656131915728166765378193_data = {"mdsDat": {"x": [0.00862536815363149, -0.26287665728974025, 0.2759493197433995, 0.207575372254332, -0.08272386876238177, -0.16392367801548519, 0.017374143916244214], "y": [-0.24568844847913515, 0.20413334220753043, 0.1664230860210652, 0.057655478822764075, 0.0861269265836764, -0.05339927433872917, -0.2152511108171716], "topics": [1, 2, 3, 4, 5, 6, 7], "cluster": [1, 1, 1, 1, 1, 1, 1], "Freq": [16.595482153253478, 8.026220275747027, 14.418251078156727, 15.716054436852575, 9.604502587521617, 18.678564024239453, 16.960925444229122]}, "tinfo": {"Term": ["eten", "nacht", "drinken", "bed", "maken", "huid", "helpen", "pijn", "graag", "last", "slapen", "slaap", "hulp", "kamer", "water", "familie", "licht", "gang", "dhr", "melden", "maaltijd", "samen", "zelfstandig", "deel", "lijken", "vertonen", "klagen", "doen", "rustig", "weigeren", "slaap", "liggen", "wakker", "nacht", "uur", "klaargemaken", "toilet", "tand", "poetsen", "aankleden", "gebitsprothese", "incontinentie", "verschoond", "ongeluk", "slapen", "gedoucht", "letsel", "lift", "klaarmaken", "assistentie", "badkamer", "gleed", "schoonmaken", "douchten", "opfrissen", "aangekleed", "scheef", "haar", "klaarma", "verzorgende", "comfortabel", "bed", "gelukkig", "vallen", "aantrekken", "helpen", "keer", "transfer", "hulp", "wassen", "kleding", "dag", "gaan", "mevrouw", "tillift", "zelfstandig", "vanochtend", "extra", "nodig", "onrustig", "rustig", "goed", "vandaag", "deel", "nam", "luistren", "kleinkind", "kleindochter", "recreatiezaal", "glimlach", "ontdekken", "bezoeken", "fotoboek", "voorlezen", "aandachtig", "recreatieruimte", "klassiek", "bingo", "aanwezig", "stoelgymnastiek", "wondje", "vogel", "sinaasappelsap", "winnen", "geheugentraining", "straalen", "concentreren", "verrassen", "wondverzorging", "groep", "bespreking", "deelde", "desinfecteren", "nieuw", "las", "tijdschrift", "doen", "enthousiast", "krant", "zorgplan", "genoot", "bezoek", "oud", "ontvangen", "favoriet", "verhaal", "vroeg", "herinnering", "samen", "nemen", "nooten", "zichtbaar", "muziek", "medebewoner", "kijken", "genieten", "maken", "vanmiddag", "huiskamer", "lijken", "rustig", "vanochtend", "krijgen", "vandaag", "teken", "reinigen", "wond", "tekenen", "verband", "oedeem", "enkel", "ontvelling", "vertonen", "smetplekk", "zinkzalf", "ingesmeeren", "diarree", "verbinden", "decubitus", "hiel", "ben", "decubituswond", "pleister", "afgedekken", "dragen", "infectie", "huidplooien", "preventie", "smetplekken", "stuit", "preventief", "schaafwond", "ten", "beschermen", "gat", "cr\u00e8me", "vertoon", "huid", "verwardheid", "aanbrengen", "irritatie", "zalf", "rood", "\u00efnspecteren", "behandelen", "plek", "roodheid", "houden", "adviseren", "speciaal", "constateren", "jeuk", "schoongemaken", "advies", "last", "regelmatig", "been", "dhr", "mevrouw", "goed", "melden", "pijn", "duizeligheid", "onderrug", "hoofdpijn", "bloeddruk", "scherp", "hevig", "paracetamol", "duizelig", "steken", "rugklacht", "zeuren", "ademhaling", "kortademigheid", "ademhaal", "rapporteren", "zuurstof", "klaagde", "zwaar", "koelen", "toedienen", "rugpijn", "warmte", "ervaren", "vlek", "allergisch", "gevoelig", "inspanning", "verergering", "ingelast", "arts", "meten", "behandeling", "onderzoek", "klacht", "monitoren", "kramp", "opstaan", "misselijkheid", "licht", "aanhouden", "klagen", "eventueel", "melden", "toenemen", "last", "voelen", "gevoel", "verlichting", "observatie", "mogelijk", "verpleegkundig", "rust", "overleg", "extra", "controleren", "vanochtend", "medicatie", "dhr", "geven", "advies", "bed", "blijven", "lijken", "mw", "mevrouw", "familie", "nagel", "geknipt", "week", "dienst", "technisch", "sleutel", "verzoek", "stelen", "lucht", "bladren", "gevijld", "nagelverzorging", "doorgeven", "geloven", "wachten", "medewerker", "indienen", "fam", "zon", "multidisciplinair", "koffiepauze", "bus", "beschuldigen", "grap", "voordeur", "\u00ebleveren", "teennagel", "update", "gewichtsverlie", "psychol ...

# %%
# Function to calculate topic distributions
def get_topic_distributions(lda_model, corpus):
    topic_distributions = []

    for doc_bow in corpus:
        doc_topics = lda_model.get_document_topics(doc_bow, minimum_probability=0)
        topic_distribution = {f'topic_{i}': 0 for i in range(num_topics)}
        for topic, prob in doc_topics:
            topic_distribution[f'topic_{topic}'] = prob
        topic_distributions.append(topic_distribution)

    return topic_distributions

# %%
# Calculate topic distributions for all documents
train_topic_dists = get_topic_distributions(lda_model, corpus_train)
test_topic_dists = get_topic_distributions(lda_model, corpus_test)
valid_topic_dists = get_topic_distributions(lda_model, corpus_valid)

# %%
# Add topic distributions to DataFrames
for topic in range(num_topics):
    train_df[f'topic_{topic}'] = [dist[f'topic_{topic}'] for dist in train_topic_dists]
    test_df[f'topic_{topic}'] = [dist[f'topic_{topic}'] for dist in test_topic_dists]
    valid_df[f'topic_{topic}'] = [dist[f'topic_{topic}'] for dist in valid_topic_dists]

# %% [markdown]
# ## Word embeddings

# %%
# Prepare text data for word embeddings
train_texts = [doc.split() for doc in train_df['text_clean']]  # Splits in tokens
# Train Word2Vec-model
word2vec_model = Word2Vec(sentences=train_texts, vector_size=50, window=5, min_count=1, workers=4)

word2vec_model_path = '../../models/agitation/word2vec_model'
word2vec_model.save(word2vec_model_path)
print(f"Word2Vec-model opgeslagen in: {word2vec_model_path}")
# Out:
# Word2Vec-model opgeslagen in: ../../models/agitation/word2vec_model

# %%
# Function to calculate document embeddings
def calculate_document_embedding(text, model):
    embeddings = [model.wv[word] for word in text.split() if word in model.wv]

    if not embeddings:
        return pd.Series(np.zeros(model.vector_size))

    mean_embedding = np.mean(embeddings, axis=0)
    return pd.Series(mean_embedding)

# %%
# Calculate document embeddings and add to DataFrames
embedding_columns = [f'embedding_{i}' for i in range(word2vec_model.vector_size)]
train_df[embedding_columns] = train_df['text_clean'].apply(lambda x: calculate_document_embedding(x, word2vec_model))

test_df[embedding_columns] = test_df['text_clean'].apply(lambda x: calculate_document_embedding(x, word2vec_model))
valid_df[embedding_columns] = valid_df['text_clean'].apply(lambda x: calculate_document_embedding(x, word2vec_model))

# %%
# Example usage of the trained model
word_embedding = word2vec_model.wv['moeder']
print(word_embedding)
# Out:
# [-0.23683262  0.29818746  0.07666711  0.2315735  -1.0272827  -0.20292939
#   0.70137936  1.3539569  -0.74706477  1.4358914  -0.23266031 -1.5551106
#  -0.15167263  0.35943106 -0.813052    1.161332    0.7613403  -0.60778314
#  -1.07401    -0.6047336  -0.8561198   0.66267985  0.9302653  -1.904583
#   0.11186823  0.28705695 -0.307924    0.07164227 -0.92849004 -0.06948316
#   0.5339329   0.84416133  0.63771635  0.3100294  -0.4430851   1.1684871
#  -0.12328997  1.1089332   0.4738793  -1.5246019   0.6062152   0.17909065
#  -1.0868143  -0.90154886  1.013482   -0.7312704  -0.5572378  -0.7296236
#  -0.49709335  1.0671574 ]

# %%
# Find words most similar to 'toilet'
similar_words = word2vec_model.wv.most_similar('verdrietig', topn=10)

for word, similarity in similar_words:
    print(f"Word: {word}, Similarity: {similarity}")
# Out:
# Word: boos, Similarity: 0.9740512371063232
# Word: gedachte, Similarity: 0.9732332825660706
# Word: denkbeeldig, Similarity: 0.9722696542739868
# Word: weglopen, Similarity: 0.9714231491088867
# Word: raam, Similarity: 0.9709116816520691
# Word: mens, Similarity: 0.9691937565803528
# Word: frustreren, Similarity: 0.9659017324447632
# Word: verstoppen, Similarity: 0.9650220274925232
# Word: teruglopen, Similarity: 0.9638254642486572
# Word: verdwalen, Similarity: 0.9635396003723145

# %%
# Save DataFrames
train_df.to_csv('../../data/agitation_train.csv', index=False)
test_df.to_csv('../../data/agitation_test.csv', index=False)
valid_df.to_csv('../../data/agitation_valid.csv', index=False)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25864 entries, 12829 to 31626
# Data columns (total 60 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   text          25864 non-null  object
#  1   label         25864 non-null  int64
#  2   text_clean    25864 non-null  object
#  3   topic_0       25864 non-null  float32
#  4   topic_1       25864 non-null  float32
#  5   topic_2       25864 non-null  float32
#  6   topic_3       25864 non-null  float32
#  7   topic_4       25864 non-null  float32
#  8   topic_5       25864 non-null  float32
#  9   topic_6       25864 non-null  float32
#  10  embedding_0   25864 non-null  float32
#  11  embedding_1   25864 non-null  float32
#  12  embedding_2   25864 non-null  float32
#  13  embedding_3   25864 non-null  float32
#  14  embedding_4   25864 non-null  float32
#  15  embedding_5   25864 non-null  float32
#  16  embedding_6   25864 non-null  float32
#  17  embedding_7   25864 non-null  float32
#  18  embedding_8   25864 non-null  float32
#  19  embedding_9   25864 non-null  float32
#  20  embedding_10  25864 non-null  float32
#  21  embedding_11  25864 non-null  float32
#  22  embedding_12  25864 non-null  float32
#  23  embedding_13  25864 non-null  float32
#  24  embedding_14  25864 non-null  float32
#  25  embedding_15  25864 non-null  float32
#  26  embedding_16  25864 non-null  float32
#  27  embedding_17  25864 non-null  float32
#  28  embedding_18  25864 non-null  float32
#  29  embedding_19  25864 non-null  float32
#  30  embedding_20  25864 non-null  float32
#  31  embedding_21  25864 non-null  float32
#  32  embedding_22  25864 non-null  float32
#  33  embedding_23  25864 non-null  float32
#  34  embedding_24  25864 non-null  float32
#  35  embedding_25  25864 non-null  float32
#  36  embedding_26  25864 non-null  float32
#  37  embedding_27  25864 non-null  float32
#  38  embedding_28  25864 non-null  float32
#  39  embedding_29  25864 non-null  float32
#  40  embedding_30  25864 non-null  float32
#  41  embedding_31  25864 non-null  float32
#  42  embedding_32  25864 non-null  float32
#  43  embedding_33  25864 non-null  float32
#  44  embedding_34  25864 non-null  float32
#  45  embedding_35  25864 non-null  float32
#  46  embedding_36  25864 non-null  float32
#  47  embedding_37  25864 non-null  float32
#  48  embedding_38  25864 non-null  float32
#  49  embedding_39  25864 non-null  float32
#  50  embedding_40  25864 non-null  float32
#  51  embedding_41  25864 non-null  float32
#  52  embedding_42  25864 non-null  float32
#  53  embedding_43  25864 non-null  float32
#  54  embedding_44  25864 non-null  float32
#  55  embedding_45  25864 non-null  float32
#  56  embedding_46  25864 non-null  float32
#  57  embedding_47  25864 non-null  float32
#  58  embedding_48  25864 non-null  float32
#  59  embedding_49  25864 non-null  float32
# dtypes: float32(57), int64(1), object(2)
# memory usage: 6.4+ MB
