# %% [markdown]
# # Careplan generation: Data cleaning
#
# **Author:** Eva Rombouts
# **Date:** 2024-07-21
# **Version:** 0.1
#
# ### Description

# %%
# Environment setup
import os

def check_environment():
    try:
        import google.colab
        return "Google Colab"
    except ImportError:
        return "Local Environment"

env = check_environment()

if env == "Google Colab":
    print("Running in Google Colab")
    # !pip install -q datasets
    from google.colab import drive, userdata
    drive.mount('/content/drive')
    os.chdir('/content/drive/My Drive/Colab Notebooks/GenCareAI/scripts')
    HF_TOKEN = userdata.get('HF_TOKEN')
else:
    print("Running in Local Environment")
    # !pip install -q
    from dotenv import load_dotenv
    load_dotenv()
    HF_TOKEN = os.getenv('HF_TOKEN')
# Out:
# Running in Local Environment

# %%
import pandas as pd
from datasets import load_dataset

# %%
dataset = load_dataset("ekrombouts/Galaxy_records", token=HF_TOKEN)
df_records = dataset['train'].to_pandas()

df = (
    df_records
    .dropna(subset=['note']) 
    .groupby(['ct_id', 'month'])['note']
    .apply(lambda x: '- ' + '\n- '.join(x))
    .reset_index(name='notes')
)

print(df.head())
print(100*'*')
print(df['notes'][0])
# Out:
#    ct_id  month                                              notes
# 0      1      1  - Meneer heeft vanochtend hulp gehad bij het a...
# 1      1      2  - Meneer heeft vanochtend hulp gehad bij het a...
# 2      1      3  - Er is een lichte verbetering in zijn lichame...
# 3      1      4  - Meneer vertoonde vanochtend wat tekenen van ...
# 4      1      5  - Meneer had vanmorgen moeite met opstaan vanw...
# ****************************************************************************************************
# - Meneer heeft vanochtend hulp gehad bij het aankleden en is daarna gaan ontbijten. Hij had wat moeite met het herkennen van zijn kleding, maar kon uiteindelijk zelfstandig eten.
# - Tijdens de lunch had meneer wat hulp nodig bij het snijden van zijn eten. Hij was rustig en genoot van zijn maaltijd. Diabetesmanagement werd in de gaten gehouden.
# - In de middag heeft meneer deelgenomen aan een puzzelactiviteit en was hier erg geconcentreerd mee bezig. Zijn mobiliteit met de rollator werd regelmatig gecheckt.
# - Vanmorgen had meneer wat hulp nodig bij de toiletgang en het wassen. Zijn bloeddruk en bloedsuiker werden gecontroleerd en waren binnen normale waarden.
# - Tijdens de lunch was meneer wat vergeetachtig en wist niet meer wat voor dag het was. Hij had ondersteuning nodig bij het eten en drinken.
# - In de middag heeft meneer wat wandelingen gemaakt met de rollator onder begeleiding. Zijn rustige en vriendelijke houding viel op bij het personeel.
# - Meneer had vanochtend wat meer hulp nodig bij het aankleden vanwege verhoogde verwardheid. Zijn diabetesmanagement en bloeddruk werden extra gecontroleerd.
# - Tijdens de lunch was meneer erg rustig en genoot van zijn maaltijd. Hij vertelde verhalen over vroeger en kon zich deze heel levendig herinneren.
# - In de middag heeft meneer deelgenomen aan een groepsactiviteit en was hier vrolijk en enthousiast over. Zijn mobiliteit met de rollator was stabiel.
# - Client had vanmorgen wat moeite met aankleden, hierbij geholpen. Geen tekenen van pijn of ongemak.
# - Bloedsuikerniveau van client gecontroleerd en genoteerd, binnen normale waarden. Geen bijzonderheden gemeld.
# - Client deelgenomen aan puzzelactiviteit, genoot zichtbaar. Stapsgewijs begeleid tijdens het avondeten.
# - Client vanmorgen zelfstandig naar toilet kunnen gaan, geen urineverlies geconstateerd. Mobiliteit lijkt stabiel.
# - Verward gedrag opgemerkt, gerustgesteld en aandacht gegeven. Geen onrust of agressie getoond.
# - Met client wandeling gemaakt buiten, gelet op veiligheid in verband met mogelijke valgevaar. Positieve interactie met andere bewoners.
# - Ontbijt genuttigd met hulp, client rustig en meegaand. Geen klachten gemeld tijdens de maaltijd.
# - Medicatie toegediend volgens schema, client nam de medicatie zonder problemen in. Aanwezigheid van medicatie gecontroleerd.
# - Tijdens groepsactiviteit vertoonde client tekenen van vermoeidheid, kort rustmoment ingelast. Aanwezigheid en betrokkenheid bij de activiteit bleef.
# - Dhr zijn ochtendverzorging verliep rustig en gestructureerd. Hij liet zich helpen bij het aankleden en genoot van zijn ontbijt. Tijdens de groepsactiviteit vertoonde hij interesse in het puzzelen en slaagde erin om een puzzel af te maken.
# - Dhr had na de lunch behoefte aan een rustmoment en kon even bijkomen op zijn eigen kamer. Zijn suikerspiegel werd gecontroleerd en bleek stabiel. Hij was alert en meewerkend bij het innemen van zijn medicatie.
# - Dhr nam deel aan het avondeten en at met smaak. Hij had wat moeite met het gebruik van zijn bestek, maar na een reminder kon hij zelfstandig verder eten. Zijn mobiliteit leek geen belemmering te vormen tijdens de maaltijd.
# - Ochtendverzorging van dhr verliep vlot. Hij had zijn bloedsuikerwaarden gecontroleerd en deze waren binnen normaal bereik. Tijdens het ochtendprogramma deed dhr actief mee met de geheugentraining en beantwoordde vragen correct.
# - Dhr kreeg na de lunch bezoek van zijn familie, wat hem duidelijk veel plezier deed. Hij vertelde anekdotes en herinneringen uit zijn jeugd, waardoor zijn ogen begonnen te fonkelen van blijdschap. De interactie met zijn familie leek hem goed te doen.
# - Dhr vertoonde na het avondeten wat onrustig gedrag en liep heen en weer in de gang. Toen hij gerustgesteld werd door het personeel, kalmeerde hij en keerde terug naar zijn kamer. Hij had behoefte aan wat extra aandacht en geruststelling.
# - Dhr maakte vanochtend een wandeling in de tuin, waar hij duidelijk van genoot. Hij keek naar de bloemen en luisterde naar de vogels, waardoor zijn gemoedstoestand verbeterde. Bij terugkomst werd hij rustiger en ontspannen.
# - Dhr nam deel aan de middagactiviteit van bakken en genoot van het maken van koekjes. Hij hielp met het mixen van het deeg en genoot van de geur van vers gebakken koekjes. Tijdens het proeven straalde hij van plezier.
# - Dhr had na het avondeten behoefte aan rust en ontspanning. Hij werd geholpen met het klaarmaken voor de nacht en genoot van de aandacht die hij kreeg. Zijn suikerniveau werd gecontroleerd en was stabiel, waardoor hij rustig in slaap viel.
# - Dhr. geholpen met aankleden en toiletgang. Diabetestest uitgevoerd, waarden binnen normale range.
# - Mw. ondersteund tijdens lunch. Bloeddruk gemeten, was stabiel. Gezamenlijke activiteit met puzzelen gedaan.
# - Dhr. naar buiten begeleid voor een korte wandeling. Tijdens de wandeling rustig en geïnteresseerd in omgeving.
# - Dhr. moeite met aankleden, extra tijd en geduld nodig. Bloedsuikerwaarden gecontroleerd en juiste medicatie gegeven.
# - Mw. had moeite met insuline-injectie. Geholpen met injectie en vervolgens lunch genuttigd. Samen spelletje gespeeld.
# - Dhr. rustig laten zitten in tuinkamer met uitzicht op de tuin. Ontspannen sfeer en genoot van moment van rust.
# - Mw. had onrustige nacht, meldde pijn in schouder. Overleg met verpleging en arts voor pijnbestrijding. Rustige start van de dag.
# - Dhr. aandacht nodig bij de lunch, verwarde momenten. Begeleid naar rustige plek en afgeleid met favoriete puzzel.
# - Mw. deelgenomen aan bakactiviteit, genoot van gezamenlijke bezigheid. Avondmaaltijd goed verlopen en rustig avondprogramma.
# - Meneer is vanochtend geholpen met wassen en scheren. Hij was rustig tijdens de verzorging en werkte goed mee.
# - Tijdens de lunch had meneer moeite met zelfstandig eten. Er is extra hulp geboden om ervoor te zorgen dat hij voldoende voedingsstoffen binnenkrijgt.
# - Meneer was vanmiddag onrustig en leek verward. Door hem gerust te stellen en afleiding te bieden met een puzzel, werd hij kalmer.
# - Er is geconstateerd dat meneer vanmorgen zijn bed nat heeft gemaakt. Het incontinentiemateriaal is vervangen en er wordt extra aandacht besteed aan het controleren van incontinentie.
# - Tijdens de geheugentraining vanmiddag leek meneer meer moeite te hebben met het herinneren van foto's. Er is besloten om de oefeningen rustig aan op te bouwen.
# - Meneer had vanavond last van hoofdpijn. Na het geven van een pijnstiller en extra rust, leek de pijn af te nemen.
# - Tijdens het ochtendritueel had meneer moeite met opstaan en lopen. Er is extra ondersteuning geboden om valincidenten te voorkomen.
# - Meneer was vandaag erg rustig en genoot van het maken van een puzzel. Hij leek ontspannen en tevreden met de activiteit.
# - Tijdens het avondeten had meneer hulp nodig bij het kiezen van de maaltijd. Er is samen met hem gezocht naar een optie die hem aansprak.

# %%
df.to_csv('../data/df_careplans.csv')
