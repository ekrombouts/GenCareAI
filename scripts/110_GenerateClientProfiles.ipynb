# %% [markdown]
# <a href="https://colab.research.google.com/github/ekrombouts/GenCareAI/blob/main/scripts/110_GenerateClientProfiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GenCare AI: Generating client profiles
#
# **Author:** Eva Rombouts
# **Date:** 2024-06-01
# **Updated:** 2024-06-13
# **Version:** 1.2
#
# ### Description
# This script generates synthetic healthcare data for NLP experiments. It generates diverse client profiles for a psychogeriatric ward using the OpenAI GPT-4 model.
#
# The output parser uses a structure called ClientProfile, which is created with Pydantic models. Pydantic helps define and validate the output for each client profile, ensuring that each profile has the right format and contains the necessary information.
#
# The goal is to produce a comprehensive and varied dataset of client profiles for use in a psychogeriatric setting, avoiding repetitive or deterministic outputs. To achieve this, we use GPT-4 with a high temperature setting to enhance variability. Additionally, each query generates multiple profiles to further ensure diversity.

# %% [markdown]
# ### Imports and constants

# %%
import os
# Determines the current environment (Google Colab or local)
def check_environment():
    try:
        import google.colab
        return "Google Colab"
    except ImportError:
        pass

    return "Local Environment"

# %%
# Installs and settings depending on the environment
# When running in CoLab, the Google drive is mounted and necessary packages are installed.
# Data paths are set and API keys retrieved

env = check_environment()

if env == "Google Colab":
    print("Running in Google Colab")
    # !pip install -q langchain langchain_core langchain_openai langchain_community
    from google.colab import drive, userdata
    drive.mount('/content/drive')
    DATA_DIR = '/content/drive/My Drive/Colab Notebooks/GenCareAI/data'
    OPENAI_API_KEY = userdata.get('GCI_OPENAI_API_KEY')
    HF_TOKEN = userdata.get('HF_TOKEN')
else:
    print("Running in Local Environment")
    # !pip install python-dotenv langchain langchain_core langchain-community langchain_openai
    DATA_DIR = '../data'
    from dotenv import load_dotenv
    load_dotenv()
    OPENAI_API_KEY = os.getenv('GCI_OPENAI_API_KEY')
    HF_TOKEN = os.getenv('HF_TOKEN')
# Out:
# Running in Local Environment

# %%
import os
import pandas as pd
from typing import List
from langchain.output_parsers import PydanticOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_openai import ChatOpenAI
from langchain_community.callbacks import get_openai_callback

# %%
# Constants and Configurations
# The ward name will be used in the filename. Practical when performing multiple
# experiments
WARD_NAME = 'Tulip'
FN_PROFILES = os.path.join(DATA_DIR, f'gcai_client_profiles_{WARD_NAME}.csv')
# Per query eight profiles are generated. The query is run NUM_WINGS times, so
# when NUM_WINGS is set to 3 the total number of client profiles generated is 24.
NUM_WINGS = 3
# GPT-4o yields better, more diverse results.
MODEL_PROFILES = 'gpt-4o-2024-05-13'
TEMP = 1.0

# %% [markdown]
# ### Data

# %%
# Definition of Pydantic model to structure the client profile data
class ClientProfile(BaseModel):
    naam: str = Field(description="naam van de client (Meneer/Mevrouw Voornaam Achternaam, gebruik een naam die je normaal niet zou kiezen)")
    type_dementie: str = Field(description="type dementie (Alzheimer, gemengde dementie, vasculaire dementie, lewy body dementie, parkinsondementie, FTD: varieer, de kans op Alzheimer, gemengde en vasculaire dementie is het grootst)")
    somatiek: str = Field(description="lichamelijke klachten")
    # biografie: str = Field(description="een korte beschrijving van karakter en relevante biografische gegevens (vermijd stereotypen in beroep en achtergrond)")
    adl: str = Field(description="beschrijf welke ADL hulp de cliënt nodig heeft")
    mobiliteit: str = Field(description="beschrijf de mobiliteit (bv rolstoelafhankelijk, gebruik rollator, valgevaar)")
    gedrag: str = Field(description="beschrijf voor de zorg relevante aspecten van cognitie en probleemgedrag. Varieer met de ernst van het probleemgedrag van rustige cliënten, gemiddeld onrustige cliënten tot cliënten die fors apathisch, onrustig, angstig, geagiteerd of zelfs agressief kunnen zijn")

# Pydantic model to hold multiple client profiles
class ClientProfiles(BaseModel):
    clients: List[ClientProfile]

# %% [markdown]
# ### Functions

# %%
def generate_data(chain_client_profiles, num_wings):
    all_data = []
    for i in range(num_wings):
        print(f'Generating data for wing{i+1}')
        result = chain_client_profiles.invoke({})
        if result is None or not hasattr(result, 'clients'):
            raise ValueError("No valid response received from the model.")
        data = [client.dict() for client in result.clients]
        all_data.extend(data)
    return pd.DataFrame(all_data)

# %%
def add_client_id(df):
    df['client_id'] = range(1, len(df) + 1)
    return df[['client_id', 'naam', 'type_dementie', 'somatiek', 'adl', 'mobiliteit', 'gedrag']]

# %%
def save_data(df, file_path):
    print(f"Data saved successfully to {file_path}.")
    df.to_csv(file_path, index=False)

# %%
def main(file_path, chain_client_profiles, num_wings):
    if os.path.exists(file_path):
        print("Data file found. Loading data...")
        return pd.read_csv(file_path)
    else:
        print("Data file not found. Generating new data...")

        with get_openai_callback() as cb:
            df = generate_data(chain_client_profiles=chain_client_profiles, num_wings=num_wings)
            print("Data generated successfully.\n")
            print(cb)

        df_with_id = add_client_id(df)
        save_data(df_with_id, file_path)
        return df_with_id

# %% [markdown]
# ### Model initialization

# %%
model= ChatOpenAI(api_key=OPENAI_API_KEY, temperature=TEMP, model=MODEL_PROFILES)

# %%
pyd_parser = PydanticOutputParser(pydantic_object=ClientProfiles)

# %% [markdown]
# ### Prompt template

# %%
PT_client_profiles = PromptTemplate(
    template = """
Schrijf acht profielen van cliënten die zijn opgenomen op een psychogeriatrische afdeling van het verpleeghuis. Hier wonen mensen met een gevorderde dementie met een hoge zorgzwaarte.
Zorg dat de profielen erg van elkaar verschillen.

{format_instructions}
""",
    input_variables=[],
    partial_variables={"format_instructions": pyd_parser.get_format_instructions()},
)

# Format the prompt for the example library
P_client_profiles = PT_client_profiles.format(profile="profile", scenario="scenario")
print(P_client_profiles)
# Out:
# Schrijf acht profielen van cliënten die zijn opgenomen op een psychogeriatrische afdeling van het verpleeghuis. Hier wonen mensen met een gevorderde dementie met een hoge zorgzwaarte.
# Zorg dat de profielen erg van elkaar verschillen.
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"properties": {"clients": {"title": "Clients", "type": "array", "items": {"$ref": "#/definitions/ClientProfile"}}}, "required": ["clients"], "definitions": {"ClientProfile": {"title": "ClientProfile", "type": "object", "properties": {"naam": {"title": "Naam", "description": "naam van de client (Meneer/Mevrouw Voornaam Achternaam, gebruik een naam die je normaal niet zou kiezen)", "type": "string"}, "type_dementie": {"title": "Type Dementie", "description": "type dementie (Alzheimer, gemengde dementie, vasculaire dementie, lewy body dementie, parkinsondementie, FTD: varieer, de kans op Alzheimer, gemengde en vasculaire dementie is het grootst)", "type": "string"}, "somatiek": {"title": "Somatiek", "description": "lichamelijke klachten", "type": "string"}, "adl": {"title": "Adl", "description": "beschrijf welke ADL hulp de cli\u00ebnt nodig heeft", "type": "string"}, "mobiliteit": {"title": "Mobiliteit", "description": "beschrijf de mobiliteit (bv rolstoelafhankelijk, gebruik rollator, valgevaar)", "type": "string"}, "gedrag": {"title": "Gedrag", "description": "beschrijf voor de zorg relevante aspecten van cognitie en probleemgedrag. Varieer met de ernst van het probleemgedrag van rustige cli\u00ebnten, gemiddeld onrustige cli\u00ebnten tot cli\u00ebnten die fors apathisch, onrustig, angstig, geagiteerd of zelfs agressief kunnen zijn", "type": "string"}}, "required": ["naam", "type_dementie", "somatiek", "adl", "mobiliteit", "gedrag"]}}}
# ```

# %%
chain_client_profiles = PT_client_profiles | model | pyd_parser

# %% [markdown]
# ## Main workflow

# %%
if __name__ == "__main__":
    df = main(file_path=FN_PROFILES, chain_client_profiles=chain_client_profiles, num_wings=NUM_WINGS)
# Out:
# Data file found. Loading data...

# %%
df.head(24)
# Out:
#     client_id                       naam  \
# 0           1        Meneer Henk Timmers
# 1           2    Mevrouw Lize Verbruggen
# 2           3        Meneer Arjan Klerks
# 3           4        Mevrouw Mia Janssen
# 4           5   Meneer Theo Boterenbrood
# 5           6    Mevrouw Sophie Brandsma
# 6           7    Meneer Karel Dijkhuizen
# 7           8        Mevrouw Eva Kuipers
# 8           9  Mevrouw Eva van der Zwaan
# 9          10      Meneer Lucas de Waard
# 10         11     Mevrouw Sofie Kleiberg
# 11         12     Meneer Bas Groenendaal
# 12         13           Mevrouw Anja Vos
# 13         14        Meneer Guus de Jong
# 14         15  Mevrouw Louise Nieuweboer
# 15         16        Meneer Kaj van Riet
# 16         17     Mevrouw Clara de Vries
# 17         18             Meneer Jan Bos
# 18         19        Mevrouw Bep Janssen
# 19         20        Meneer Wim van Dijk
# 20         21    Mevrouw Annie Vermeulen
# 21         22       Meneer Karel de Jong
# 22         23      Mevrouw Lisa Hendriks
# 23         24          Meneer Theo Smits
#
#                                  type_dementie  \
# 0                                    Alzheimer
# 1                          Vasculaire dementie
# 2                                          FTD
# 3                            Parkinsondementie
# 4                            Gemengde dementie
# 5                           Lewy body dementie
# 6                          Vasculaire dementie
# 7                                    Alzheimer
# 8                                    Alzheimer
# 9                          Vasculaire dementie
# 10                          Lewy-body dementie
# 11              Frontotemporale dementie (FTD)
# 12  Gemengde dementie (Alzheimer en vasculair)
# 13                           Parkinsondementie
# 14                                   Alzheimer
# 15  Gemengde dementie (Alzheimer en vasculair)
# 16                                   Alzheimer
# 17                         Vasculaire dementie
# 18                          Lewy body dementie
# 19              Frontotemporale dementie (FTD)
# 20                                   Alzheimer
# 21                           Gemengde dementie
# 22                           Parkinsondementie
# 23                         Vasculaire dementie
#
#                                              somatiek  \
# 0                            Diabetes, hoge bloeddruk
# 1                                 Reumatoïde artritis
# 2             Geen significante lichamelijke klachten
# 3                              Parkinson, osteoporose
# 4                                Hartproblemen, astma
# 5                               Chronische bronchitis
# 6      CVA (beroerte) restverschijnselen, hypertensie
# 7                Chronische nierziekte, gehoorverlies
# 8                           Artrose en hoge bloeddruk
# 9                                     Diabetes type 2
# 10           Parkinsonisme en frequente valincidenten
# 11                  Epilepsie en hartritmestoornissen
# 12                            Astma en hoge bloeddruk
# 13                              Chronische nierziekte
# 14            Osteoporose en spijsverteringsproblemen
# 15          Chronische obstructieve longziekte (COPD)
# 16                          Diabetes type 2, artritis
# 17                Hoge bloeddruk, chronisch hartfalen
# 18                      Milde Parkinsonisme, maagzuur
# 19            Geen significante lichamelijke klachten
# 20                         Osteoporose, incontinentie
# 21                                      COPD, artrose
# 22                     Parkinson ziekte, lage rugpijn
# 23  Verlamming aan linkerzijde door beroerte, inco...
#
#                                                   adl  \
# 0   Heeft hulp nodig bij het aankleden en douchen....
# 1   Volledig afhankelijk van hulp bij ADL-activite...
# 2   Heeft minimale hulp nodig bij ADL, alleen bege...
# 3   Heeft uitgebreide hulp nodig bij ADL vanwege t...
# 4   Zelfstandig eten en lichte ADL-activiteiten, m...
# 5   Heeft volledige hulp nodig bij alle ADL-activi...
# 6   Heeft ondersteuning nodig bij eten en volledig...
# 7   Heeft supervisie nodig bij alle ADL-activiteit...
# 8   Heeft hulp nodig bij douchen en aankleden, kan...
# 9   Volledige hulp nodig bij persoonlijke verzorgi...
# 10        Heeft hulp nodig bij alle ADL-activiteiten.
# 11  Kan zich aankleden met enige hulp, heeft hulp ...
# 12    Full-time zorg nodig bij alle ADL-activiteiten.
# 13  Heeft hulp nodig bij douchen, aankleden en naa...
# 14  Heeft hulp nodig bij douchen en aankleden, ete...
# 15  Volledige zorg nodig bij ADL, lichaamshygiëne ...
# 16  Heeft hulp nodig bij alle dagelijkse activitei...
# 17  Heeft hulp nodig bij baden en aankleden, maar ...
# 18  Hulp nodig bij gecompliceerde taken zoals bade...
# 19  Heeft voornamelijk reminders en lichte hulp no...
# 20                Volledige assistentie bij ADL-taken
# 21  Heeft hulp nodig bij wassen, aankleden, en som...
# 22        Hulp nodig bij alle dagelijkse activiteiten
# 23            Volledige hulp nodig bij alle ADL-taken
#
#                                            mobiliteit  \
# 0    Gebruikt een rollator; valgevaar achter aanwezig
# 1                                 Rolstoelafhankelijk
# 2   Licht onvast ter been, gebruikt soms een wande...
# 3   Rolstoelafhankelijk, maar kan kleine stukjes l...
# 4   Gebruikt rollator binnenshuis, rolstoel buiten...
# 5   Volledig rolstoelafhankelijk, zelfs voor korte...
# 6           Halfzijdig verlamd en rolstoelafhankelijk
# 7   Licht instabiel te been, gebruikt binnenshuis ...
# 8         Gebruikt een rollator, licht valgevaarlijk.
# 9                                Rolstoelafhankelijk.
# 10  Valgevaarlijk, loopt met een rollator en begel...
# 11            Licht valgevaarlijk, loopt zelfstandig.
# 12  Gebruikt een rolstoel voor langere afstanden, ...
# 13  Valgevaarlijk, loopt met een rollator en soms ...
# 14  Valveiligheid is een punt van zorg, maar zij w...
# 15                         Volledig rolstoelgebonden.
# 16  Rolstoelafhankelijk, kan enkele stappen met be...
# 17    Gebruik van een rollator binnenshuis, valgevaar
# 18  Lopen met rollator, soms wankel, risico op vallen
# 19            Zelfstandig lopen, soms onrustig dwalen
# 20                       Volledig rolstoelafhankelijk
# 21  Gebruik van een rollator, maar heeft frequente...
# 22             Lopen met rollator, neiging tot vallen
# 23                          Volledig rolstoelgebonden
#
#                                                gedrag
# 0   Heeft momenten van verwarring en vergeetachtig...
# 1   Af en toe agressieve uitbarstingen, vooral als...
# 2   Vertonen van dwangmatig gedrag en soms verbale...
# 3   Mild onrustig gedrag en vertraagd denken. Kan ...
# 4   Kan af en toe verward zijn en ‘s nachts dwalen...
# 5   Veel wisselingen in alertheid, levendige hallu...
# 6   Matig onrustig, vertoont soms impulsief gedrag...
# 7   Rustig en meestal in eigen wereld verzonken. A...
# 8   Meestal rustig maar kan verward en angstig zij...
# 9   Heeft vaak stemmingswisselingen, somber en som...
# 10  Hallucinaties en wanen, kan extreem onrustig e...
# 11  Zeer impulsief gedrag, kan agressief zijn, hee...
# 12  Meestal rustig maar kan verbaal aanstootgevend...
# 13  Ervaart vaak angst en treden hallucinaties op,...
# 14  Zeer apathisch, spreekt weinig, maar volgt een...
# 15  Zeer onrustig en klaagt veel, angstig als hij ...
# 16  Rustige cliënt, maar regelmatig vergeten waar ...
# 17  Periodes van verwardheid en soms agressief ged...
# 18  Visuele hallucinaties, soms angstig en geagiteerd
# 19  Gedragsstoornissen zoals sociaal ongepast gedr...
# 20  Apathisch gedrag, weinig reactie op prikkels, ...
# 21  Onrustig en vaak doelloos ronddwalen, soms gef...
# 22  Snel vermoeid, angstig en soms nachtelijke onrust
# 23  Communicatieproblemen, apathisch, maar reageer...
