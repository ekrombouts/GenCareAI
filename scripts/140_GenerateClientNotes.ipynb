# %% [markdown]
# # GenCare AI: Generating client records
#
# **Author:** Eva Rombouts
# **Date:** 2024-06-15
# **Updated:**
# **Version:** 1.0
#
# ### Description
# This script generates synthetic care notes and summaries for clients in a psychogeriatric ward using the OpenAI GPT-3.5-turbo model.
# The care notes are based on client profiles and scenarios generated in earlier scripts in this repo. The goal is to add as much story and variation to the notes as possible, without letting the model produce outputs that are overly creative.
# To achieve this, I use structured prompts (to help the model understand the expected content and its creative liberties), example libraries and memory integration.
# The output parser uses Pydantic models to structure and validate the care notes, ensuring proper format and content.
# Chroma is used to retrieve example care notes that are representative of the client profile and scenario.
#
# The script processes client profiles and scenarios, generates care notes, and updates summaries accordingly, creating comprehensive client records.
# The goal is to create a diverse and realistic dataset for NLP experiments in nursing homes.
#
# **Please note** that generating data with OpenAI is not free. Generating records for 24 clients with a mean of 6 months, 5 iterations per month, is appr $2,-.

# %% [markdown]
# ## Imports and constants

# %% [markdown]
# This script can be run either in Google Colab or locally.
# - Running in Google Colab:
#     - Ensure that the path names are correctly set.
# 	- Store your OpenAI API key in the Colab environment secrets.
# 	- The script includes commands to install necessary packages, but you may need to adjust or add packages based on your specific requirements.
# - Running Locally:
# 	- Create a .env file in your working directory containing your OpenAI API key.
# 	- Verify and update the path names as necessary to match your local directory structure.
# 	- Install required libraries using pip.

# %%
import os
# Determines the current environment (Google Colab or local)
def check_environment():
    try:
        import google.colab
        return "Google Colab"
    except ImportError:
        pass

    return "Local Environment"

# %%
# Installs and settings depending on the environment
env = check_environment()

if env == "Google Colab":
    print("Running in Google Colab")
    # !pip install -q langchain langchain-openai langchain-community chromadb
    from google.colab import drive, userdata
    drive.mount('/content/drive')
    DATA_DIR = '/content/drive/My Drive/Colab Notebooks/GenCareAI/data'
    OPENAI_API_KEY = userdata.get('GCI_OPENAI_API_KEY')
else:
    print("Running in Local Environment")
    # !pip install python-dotenv langchain langchain-community langchain_openai chromadb
    DATA_DIR = '../data'
    from dotenv import load_dotenv
    load_dotenv()
    OPENAI_API_KEY = os.getenv('GCI_OPENAI_API_KEY')
# Out:
# Running in Local Environment

# %%
# Imports
import random
import pandas as pd
from pprint import pprint
from typing import List

from langchain.output_parsers import PydanticOutputParser, CommaSeparatedListOutputParser
from langchain.prompts import ChatPromptTemplate 
from langchain.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_community.callbacks import get_openai_callback

# %%
# Paths to various data files and constants for the model and temperature settings.
PATH_DB_GCAI = os.path.join(DATA_DIR, 'chroma_db_gcai')
WARD_NAME = 'Tulip' # Make sure to use the same ward-name for which clientprofiles and -scenarios have been generated
PATH_PROFILES = os.path.join(DATA_DIR, f'gcai_client_profiles_{WARD_NAME}.csv')
PATH_SCENARIOS = os.path.join(DATA_DIR, f'gcai_client_scenarios_{WARD_NAME}.csv')
PATH_NOTES = os.path.join(DATA_DIR, f'gcai_client_notes_{WARD_NAME}.csv')
PATH_SUMMARIES = os.path.join(DATA_DIR, f'gcai_client_summaries_{WARD_NAME}.csv')

COLLECTION_NAME = 'anonymous_reports'
MODEL = 'gpt-3.5-turbo-0125'
MODEL_EMBEDDINGS = 'text-embedding-ada-002'
TEMP = 1.1

VERBOSE = True # Set to True for debugging / printing
TEST_CLIENT_ROW_NUMBER = 2
SEP_LINE = 100*'-'

# %% [markdown]
# ## Data

# %% [markdown]
# ### Load data

# %% [markdown]
# In the notebooks [110_GenerateClientProfiles.ipynb]() and [120_GenerateClientScenarios.ipynb](), datasets are generated with client profiles and scenarios, respectively.
#
# - ***df_profiles***: Contains one row per client. The row describes the type of dementia the client is diagnosed with, the ADL care needs, medical symptoms and diseases, mobility, and behavior.
#
# - ***df_scenarios***: Each client has zero or more scenario lines. These are referred to as month numbers, but they do not necessarily correspond to actual months.

# %%
# Load scenarios and profiles from CSV files
df_scenarios = pd.read_csv(PATH_SCENARIOS)
df_profiles = pd.read_csv(PATH_PROFILES)

if VERBOSE:
    print(df_profiles.info())
    print(df_scenarios.info())
    test_client = df_profiles.iloc[TEST_CLIENT_ROW_NUMBER] # We will be using this test client throughout the script
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   client_id      24 non-null     int64
#  1   naam           24 non-null     object
#  2   type_dementie  24 non-null     object
#  3   somatiek       24 non-null     object
#  4   adl            24 non-null     object
#  5   mobiliteit     24 non-null     object
#  6   gedrag         24 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   client_id      133 non-null    int64
#  1   month          133 non-null    object
#  2   journey        133 non-null    object
#  3   complications  133 non-null    object
#  4   num_months     133 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 5.3+ KB
# None

# %% [markdown]
# ### Functions to display the data

# %%
# Function to format the client’s profile information as a single string
def profile_as_string(profile_row, display_name=True):
    profile = ""
    if display_name:
        profile += f"Naam: {profile_row['naam']}\n"
    profile += (f"Type Dementie: {profile_row['type_dementie']}\n"
                f"Lichamelijke klachten: {profile_row['somatiek']}\n"
                f"ADL: {profile_row['adl']}\n"
                f"Mobiliteit: {profile_row['mobiliteit']}\n"
                f"Cognitie / gedrag: {profile_row['gedrag']}")
    return profile

if VERBOSE:
    print(profile_as_string(profile_row=test_client, display_name=True))
# Out:
# Naam: Meneer Arjan Klerks
# Type Dementie: FTD
# Lichamelijke klachten: Geen significante lichamelijke klachten
# ADL: Heeft minimale hulp nodig bij ADL, alleen begeleiding bij douchen en aankleden.
# Mobiliteit: Licht onvast ter been, gebruikt soms een wandelstok
# Cognitie / gedrag: Vertonen van dwangmatig gedrag en soms verbale agressie. Kan ineens roepen of zingen.

# %%
# Function to display the scenario information for a given client and month
def scenario_as_string(profile_row, month_no=1):
    client_id = profile_row['client_id']
    return df_scenarios.loc[df_scenarios['client_id'] == client_id, 'journey'].iloc[month_no - 1]
    
if VERBOSE:
    print(scenario_as_string(profile_row=test_client))
    print(scenario_as_string(profile_row=test_client, month_no=2))
# Out:
# Meneer Arjan Klerks wordt opgenomen in het verpleeghuis vanwege zijn FTD. Hij krijgt begeleiding bij ADL en gebruikt soms een wandelstok. Incidenteel vertoont hij dwangmatig gedrag en verbale agressie.
# In de tweede maand is er geen significante verandering in zijn toestand. Meneer Arjan Klerks blijft minimale hulp nodig hebben bij ADL en vertoont af en toe dwangmatig gedrag.

# %% [markdown]
# ### Define Pydantic models

# %% [markdown]
# For parsing, we use pydantic models. These are remarkably well understood by the LLM, and offer several benefits:
# - It enforces consistent output structure
# - It automates parsing of the output
# - The field description further guides the LLM model in generating appropriate responses.
# - It catches invalid data early, preventing downstream issues.
#
# In our main prompt defined below, we ask the LLM to generate multiple care notes. Our structure consists of two classes: one to structure a single note (CareNote) and a second class defined as a list of care notes (CareNotes).
#
# CareNote represents a single care note with the fields dag, tijd, and rapportage:
# - **'dag'**: Even though the sequence number of the day ("dag") isn't meaningful, it forces the model to respond with the number of days requested.
# - **'tijd'**: The field 'time' ("tijd") was chosen over 'daypart' ("dagdeel") because the model tended to link 'daypart' to breakfast, lunch, and dinner, which led to many notes describing lunch details.
# - **'rapportage'**: This is the main challenge, what it's all about...
#
# CareNotes is a container for multiple care notes, consisting of a single field **'notes'**, which is a list of CareNote instances.

# %%
#Structure for a single care note
class CareNote(BaseModel):
    dag: int = Field(description="volgnummer dag")
    tijd: str = Field(description="tijd van de rapportage (hh:mm)")
    rapportage: str = Field(description="Inhoud van de rapportage. Een rapportage beschrijft over het algemeen één zorgaspect, soms meer")

# Structure for multiple notes
class CareNotes(BaseModel):
    notes: List[CareNote]

# %% [markdown]
# ## Model initialization

# %% [markdown]
# The temperature and model settings can be configured in the constants section. I selected the OpenAI GPT-3.5-turbo model for cost-efficiency. The temperature setting of 1.1 was determined through trial and error.

# %%
# Initialize OpenAI Chat model
model = ChatOpenAI(api_key=OPENAI_API_KEY, temperature=TEMP, model=MODEL)

# %%
# Initialize CSV and pydantic parsers
csv_parser = CommaSeparatedListOutputParser()
csv_format_instructions = csv_parser.get_format_instructions()
pyd_parser = PydanticOutputParser(pydantic_object=CareNotes)

# %% [markdown]
# ## Setting up the example library

# %% [markdown]
# ### Setup Chroma

# %% [markdown]
# To improve the contextual relevance and diversity of the generated care notes, we will dynamically inject example notes into the prompts.
#
# Chroma is used in this context to select example care notes that are representative of the client profile and scenario. By using a vector database, the system can efficiently find example notes that match the specific characteristics of each client. The Chroma vector database, created [here](), contains a variety of (synthetic) notes for anonymous clients. The retriever queries this database, allowing the processing functions to access and integrate the stored example notes.
# By adding these dynamically selected examples to the prompt, this approach aims to make the generated care notes more contextually appropriate and diverse.
#
# Our approach is:
# - Initialize the Chroma Vector Database.
# - Generate Keywords: Using the LLM, keywords are generated from a client’s profile and scenario. These keywords are used to query the Chroma vector database for relevant example notes.
# - Retrieve Example Notes: Utilizing a retriever to search the vector database with the generated keywords, supplemented by additional neutral terms to ensure a broad coverage of relevant care notes.
# - Filter by Gender: Filter the retrieved example notes to exclude those with gender-specific pronouns that do not match the client’s gender, ensuring the relevance of the examples.
# - Sample Examples: Randomly sample a subset of the filtered example notes to inject into the prompts, enhancing the diversity of the generated care notes.

# %%
# Initialize Chroma vector database
vectordb = Chroma(persist_directory=PATH_DB_GCAI,
                  embedding_function=OpenAIEmbeddings(api_key=OPENAI_API_KEY, model=MODEL_EMBEDDINGS),
                  collection_name = COLLECTION_NAME
                  )

# %%
# Set up a retriever for document querying
retriever = vectordb.as_retriever(search_kwargs={"k": 20})

# %% [markdown]
# ### Keywords prompt & chain

# %%
# Template to generate key words from a client’s profile and scenario for retrieving example notes
PT_keywords = PromptTemplate(
    template = """
Geef vijf woorden die de kern weergeven van onderstaand profiel en scenario.
Geef geen namen terug.

Profiel:
{profile}

Scenario:
{scenario}

{format_instructions}
""",
    input_variables=["profile", "scenario"],
    partial_variables={"format_instructions": csv_format_instructions},)

# Format the prompt for the example library
if VERBOSE:
    P_keywords = PT_keywords.format(
        profile=profile_as_string(test_client, display_name=False), 
        scenario=scenario_as_string(test_client, month_no=1))
    print(P_keywords)
# Out:
# Geef vijf woorden die de kern weergeven van onderstaand profiel en scenario.
# Geef geen namen terug.
#
# Profiel:
# Type Dementie: FTD
# Lichamelijke klachten: Geen significante lichamelijke klachten
# ADL: Heeft minimale hulp nodig bij ADL, alleen begeleiding bij douchen en aankleden.
# Mobiliteit: Licht onvast ter been, gebruikt soms een wandelstok
# Cognitie / gedrag: Vertonen van dwangmatig gedrag en soms verbale agressie. Kan ineens roepen of zingen.
#
# Scenario:
# Meneer Arjan Klerks wordt opgenomen in het verpleeghuis vanwege zijn FTD. Hij krijgt begeleiding bij ADL en gebruikt soms een wandelstok. Incidenteel vertoont hij dwangmatig gedrag en verbale agressie.
#
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %% [markdown]
# The code below shows us the result of passing this prompt to the model. The result is a langchain_core.messages.ai.AIMessage object. The 'content' parameter holds the AI message (the response) as a string. As requested by the format instructions in the prompt, this is a comma separated 'list' of values.
# Passing this string to the CommaSeparatedListOutputParser results in an actual python list.
#
# The model often returns more than the five requested keywords. Since this has minor consequences, I accept this behavior.

# %%
if VERBOSE:
    response_keywords = model.invoke(P_keywords)
    parsed_response_keywords = csv_parser.parse(response_keywords.content)

    print(response_keywords)
    print(100 * '-')
    print(parsed_response_keywords)
    print(100 * '-')
# Out:
# content='FTD, begeleiding, dwangmatig gedrag, wandelstok, verbale agressie' response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 250, 'total_tokens': 275}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-b36d1df4-5903-49ee-af4a-952568bf919a-0' usage_metadata={'input_tokens': 250, 'output_tokens': 25, 'total_tokens': 275}
# ----------------------------------------------------------------------------------------------------
# ['FTD', 'begeleiding', 'dwangmatig gedrag', 'wandelstok', 'verbale agressie']
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Chaining it all together

# %%
# Chain the prompt template with the model and the parser
chain_keywords = PT_keywords | model | csv_parser

if VERBOSE:
    test_keywords = chain_keywords.invoke(
        {"profile": profile_as_string(test_client, display_name=False), 
         "scenario": scenario_as_string(test_client, month_no=1)})
    print(test_keywords)
# Out:
# ['FTD', 'Begeleiding', 'Agressie', 'Mobiliteit', 'Dwangmatig gedrag']

# %% [markdown]
# ### Retrieving notes for the example library

# %% [markdown]
# The next step is to invoke the retriever with the generated keywords to obtain example notes. To add more ‘neutral’ notes, we also add the keywords ‘ADL’, ‘mobility’, and ‘food and drinks’ to the list.
#
# Please note: The retriever utilizes an OpenAI embedding model (which is not free), which transforms the keywords into embeddings. These embeddings are then used to find similar notes in the initialized vector database, ensuring the retrieval of contextually relevant examples.

# %%
# Retrieves example notes from a retriever based on keywords
def get_example_notes(keywords, retriever):
    example_library = []
    example_library_topics = keywords
    example_library_topics.extend(['adl', 'mobiliteit', 'eten en drinken'])
    for i in example_library_topics:
        docs = retriever.invoke(i)
        for d in docs:
            example_library.append(d.page_content.strip('"'))
    return example_library

if VERBOSE:
    example_notes = get_example_notes(test_keywords, retriever)
    print(random.sample(example_notes,5))
    print(len(example_notes))
# Out:
# ['Tijdens het uitvoeren van de ADL activiteiten vertoonde mw. acute benauwdheidsklachten. Kortademigheid werd duidelijk bij het opstaan uit de stoel. Graag zuurstofsaturatie meten en verhogen naar behoefte.', 'Dhr vertoonde vanavond tekenen van toenemende verwardheid, onrust en wilde steeds uit bed stappen. Familie op de hoogte gebracht en situatie gemonitord.', 'Dhr uit plotselinge agressie naar medebewoners toe tijdens het spelletje, slaat met zijn handen op tafel en schreeuwt. Direct ingegrepen en dhr apart genomen voor afkoeling.', 'Familie van mevr. gevraagd naar favoriete muziek voor op de afdeling, willen graag sfeer verbeteren.', 'Overleg met verpleging over herziening zorgplan mevr. M., focus op mobiliteit en zelfredzaamheid']
# 160

# %% [markdown]
# The example notes often contain gender-specific pronouns or titles. When these are included in the prompt the model tends to generate responses with incorrect pronouns for our client. Therefore, we need to filter the example library to exclude notes that use ‘mr’ or ‘mrs’.

# %%
# Determines the gender of a client based on their name
def determine_gender(name):
    if "Mevrouw" in name:
        return 'female'
    elif "Meneer" in name:
        return 'male'
    else:
        return 'unknown'
    
if VERBOSE:
    print(f"The gender of {test_client['naam']} is: {determine_gender(test_client['naam'])}")
# Out:
# The gender of Meneer Arjan Klerks is: male

# %%
# Filters example notes by the specified gender to ensure relevance
def filter_examples_by_gender(texts, gender_to_keep):
    if gender_to_keep == 'male':
        keywords = ['mw', 'mevr', 'mvr', 'mevrouw']
    elif gender_to_keep == 'female':
        keywords = ['dhr', 'meneer']
    else:
        return texts

    def contains_keywords(text):
        text_lower = text.lower()
        return any(keyword in text_lower for keyword in keywords)

    return [text for text in texts if not contains_keywords(text)]

if VERBOSE:
    test_example_library = filter_examples_by_gender(texts=example_notes, gender_to_keep=determine_gender(test_client['naam']))
    [print('- '+item) for item in random.sample(test_example_library, 5)]
    print(f"\nOorspronkelijk aantal voorbeelden: {len(example_notes)}")
    print(f"Gefilterd aantal voorbeelden: {len(test_example_library)}")
# Out:
# - Dhr. maakte een wandeling met de rollator onder begeleiding van een verzorgende.
# - Dhr. werd plotseling agressief naar medebewoners en schudde aan deuren die op slot zaten; veilige omgeving gecre\u00eberd en rust aangeboden om de spanning te verminderen.
# - Familie van dhr. wil graag weten of fysiotherapie kan worden ingepland voor meer beweging.
# - Tijdens de ADL zat dhr. met een gefronste blik op zijn gezicht. Bij navraag gaf dhr. aan wat meer last te hebben van zijn schouders en nek vandaag. Overleggen met fysiotherapie voor mobilisatieadviezen.
# - Dhr. onrustig en verward gedrag vertoond in de avonduren, observatie en eventueel medicatie aanpassing in overweging.
#
# Oorspronkelijk aantal voorbeelden: 160
# Gefilterd aantal voorbeelden: 96

# %% [markdown]
# We'll be sampling a subset of this library

# %%
# Selects a random set of examples from the example library and returns as bulleted string
def sample_examples_as_string(example_library, num_items=3):
    random_items = random.sample(example_library, num_items)
    return '\n'.join(['- ' + item for item in random_items])

if VERBOSE:
    sampled_examples_as_string = sample_examples_as_string(test_example_library, 5)
    print(sampled_examples_as_string)
# Out:
# - Dhr vertoont herhaaldelijk uitdagend gedrag en lijkt de grenzen op te zoeken. Afleiding geboden met een simpel spel om de focus te verleggen.
# - Dhr. vertoont onrustig gedrag en trekt continu aan het verband om zijn been. Kleine wond op been geconstateerd en afgedekt met een niet-klevend verband.
# - Dhr. vertoonde vanmiddag onrustig gedrag en wilde constant opstaan uit zijn stoel. Hij leek angstig en onzeker. Extra observatie is nodig om zijn gemoedstoestand te monitoren.
# - Dhr. maakte een wandeling door de tuin onder begeleiding van een zorgmedewerker.
# - Dhr vertoont onrustig gedrag en angstige stemming zonder aanwijsbare reden. Stimuleer ontspanningstechnieken en overleg met het behandelteam over mogelijke interventies.

# %% [markdown]
# Putting it all together in a function:

# %%
# Generates an example library for a client based on their profile and scenario
def create_example_library(row, scenario):
    profile_no_name = profile_as_string(row, display_name=False)
    client_gender = determine_gender(row['naam'])

    # Invoke the example library chain to get the keywords to search for example notes relevant to this client
    keywords = chain_keywords.invoke({"profile": profile_no_name, "scenario": scenario})
    example_notes = get_example_notes(keywords=keywords,retriever=retriever)
    example_library = filter_examples_by_gender(texts=example_notes, gender_to_keep=client_gender)

    return example_library

if VERBOSE:
    example_library = create_example_library(test_client, scenario=scenario_as_string(test_client,month_no=1))
    sampled_examples_as_string = sample_examples_as_string(example_library=example_library, num_items=3)
    print(SEP_LINE)
    print(sampled_examples_as_string)
# Out:
# ----------------------------------------------------------------------------------------------------
# - Tijdens de ADL zat dhr. met een gefronste blik op zijn gezicht. Bij navraag gaf dhr. aan wat meer last te hebben van zijn schouders en nek vandaag. Overleggen met fysiotherapie voor mobilisatieadviezen.
# - Dhr is plotseling agressief en slaat tegen de tafel, mompelt onverstaanbare woorden. Lijkt plots de omgeving niet te herkennen. Dhr rustig benaderd en afgeleid naar een andere bezigheid.
# - U maakte een wandeling in het nabijgelegen park onder begeleiding van een zorgmedewerker.

# %% [markdown]
# ## Setting up the summary memory

# %% [markdown]
# ### Memory prompt & chain

# %% [markdown]
# Adding memory is important because it allows the generated care notes to reflect ongoing developments in a client’s condition and care. This ensures that each new set of notes builds on previous information, maintaining continuity in the narrative of the client’s health and daily experiences.
#
# I chose to implement memory by using a summary-based approach. This turned out to be more effective than passing the last notes directly, because it provides context through the profile and the summary, maintaining the storyline. Meanwhile, example notes are refreshed each time, preventing the model from becoming repetitive and producing the same structure repeatedly.
#
# Initially, a summary is created that includes the client’s profile and the scenario of the first month. As new care notes are generated, this summary is updated to reflect the latest information. This updated summary is then used as the context for generating subsequent notes, ensuring that the model retains and incorporates past details.
#
# In the prompt, the model is asked to update the summary based on the previous summary and the newly generated client notes.
#
# [todo: a note about the TEMP, for now, I chose to keep it relatively high]

# %%
# Template for updating the client summary based on new care notes

PT_memory = PromptTemplate(
    template = """
Hieronder staat:
1. Het profiel van een client(e) die verblijft op een psychogeriatrische afdeling van het verpleeghuis. 
2. Een samenvatting van het beloop tot de indexdatum
3. Nieuwe zorgrapportages vanaf de indexdatum

PROFIEL:
{profile}

SAMENVATTING BELOOP TOT INDEXDATUM:
{summary}

NIEUWE RAPPORTAGES:
{new_notes}

Schrijf in één alinea een nieuwe samenvatting van het beloop. Neem belangrijke gebeurtenissen en zorgvraag uit de eerdere samenvatting over en vul aan met belangrijke gebeurtenissen en zorgvraag uit de rapportages. Neem de gegevens uit het profiel niet over in de samenvatting.

In het antwoord dient uitsluitend de samenvatting van het beloop te staan, zonder aanvullende tekst.
""",
    input_variables=["profile", "summary", "new_notes"],
)

if VERBOSE:
    # Since we don't have any notes yet we'll be using example notes as new_notes
    test_new_notes = sample_examples_as_string(example_library,9)
    P_memory = PT_memory.format(profile=profile_as_string(test_client),
                                summary=scenario_as_string(test_client, month_no=1), 
                                new_notes=test_new_notes)
    print(P_memory)
# Out:
# Hieronder staat:
# 1. Het profiel van een client(e) die verblijft op een psychogeriatrische afdeling van het verpleeghuis.
# 2. Een samenvatting van het beloop tot de indexdatum
# 3. Nieuwe zorgrapportages vanaf de indexdatum
#
# PROFIEL:
# Naam: Meneer Arjan Klerks
# Type Dementie: FTD
# Lichamelijke klachten: Geen significante lichamelijke klachten
# ADL: Heeft minimale hulp nodig bij ADL, alleen begeleiding bij douchen en aankleden.
# Mobiliteit: Licht onvast ter been, gebruikt soms een wandelstok
# Cognitie / gedrag: Vertonen van dwangmatig gedrag en soms verbale agressie. Kan ineens roepen of zingen.
#
# SAMENVATTING BELOOP TOT INDEXDATUM:
# Meneer Arjan Klerks wordt opgenomen in het verpleeghuis vanwege zijn FTD. Hij krijgt begeleiding bij ADL en gebruikt soms een wandelstok. Incidenteel vertoont hij dwangmatig gedrag en verbale agressie.
#
# NIEUWE RAPPORTAGES:
# - Morgen extra fysiotherapiesessie voor dhr inplannen, dochter gaf aan dat dhr moeite heeft met mobiliteit
# - Dhr was vanmiddag erg verbaal agressief en schold het personeel uit voor dieven. Hij kon niet kalmeren en bleef maar doorratelen over gestolen spullen. Dhr naar zijn kamer gebracht om tot rust te komen en daar een kopje thee aangeboden.
# - Familiegroep wil graag op de hoogte gehouden worden van veranderingen in zorgplan en eventuele aanpassingen in medicatie.
# - Dhr uit plotseling agressie richting medebewoner omdat hij ervan overtuigd is dat deze zijn geld heeft gestolen. Dhr schreeuwt en dreigt zonder duidelijke aankondiging. Dhr apart genomen voor rust en gesprek om de situatie uit te leggen en te kalmeren.
# - Dhr is verbaal agressief en dreigt zijn kamer te verlaten omdat hij denkt dat hij te laat is voor een belangrijke afspraak. Hij maakt woeste gebaren en schreeuwt om aandacht. Dhr is rustig toegesproken en aangemoedigd om een kopje thee te drinken om te kalmeren.\
# - Dhr vertoont agressief gedrag en duwt een medebewoner weg die te dichtbij komt. Hij maakt dreigende gebaren en kan moeilijk worden gekalmeerd door het personeel.
# - Tijdelijk overgestapt naar wandelstok vanwege klachten met de rollator. Comfort lijkt beter, maar snelheid is lager.
# - Overleg met collega's over aanpassingen in zorgplan dhr, meer fysiotherapie nodig
# - Dhr was vanochtend verbaal agressief richting het zorgpersoneel. Hij schreeuwde dat hij de bus moest halen en iedereen uit de weg moest gaan. Dhr is rustig benaderd en afgeleid met een kopje thee.
#
# Schrijf in één alinea een nieuwe samenvatting van het beloop. Neem belangrijke gebeurtenissen en zorgvraag uit de eerdere samenvatting over en vul aan met belangrijke gebeurtenissen en zorgvraag uit de rapportages. Neem de gegevens uit het profiel niet over in de samenvatting.
#
# In het antwoord dient uitsluitend de samenvatting van het beloop te staan, zonder aanvullende tekst.

# %%
chain_memory = PT_memory | model

if VERBOSE:
    updated_summary = chain_memory.invoke({"profile": profile_as_string(test_client),
                                           "summary": scenario_as_string(test_client, month_no=1), 
                                           "new_notes": test_new_notes})
    test_summary_m1 = updated_summary.content
    pprint(test_summary_m1)
# Out:
# ('Meneer Arjan Klerks, opgenomen vanwege zijn FTD, vertoont verschillende '
#  'vormen van agressief gedrag, zoals verbale agressie en dreigende gebaren '
#  'naar medebewoners en personeel. Hij heeft extra fysiotherapie nodig vanwege '
#  'mobiliteitsproblemen en vertoont dwangmatig gedrag, zoals het herhaaldelijk '
#  'over gestolen spullen praten. De familie wil betrokken blijven bij eventuele '
#  "veranderingen in het zorgplan en medicatie. Er is discussie met collega's "
#  'over aanpassingen in het zorgplan en het toenemende agressieve gedrag van '
#  'meneer Klerks.')

# %% [markdown]
# ## Generating client notes

# %% [markdown]
# ### Note generation prompts & chain

# %% [markdown]
# Our goal is populate the client record by generating care notes reflecting the client profile and describing the scenario.
# In practice, the number and length of notes per day vary based on clinical circumstances. Stable clients typically have fewer and shorter notes than ill or agitated clients. (I might add this functionality in the future.) Currently, I chose to generate three notes per day. Through trial and error, I found that the model can reliably generate nine notes per prompt.
# Having a scenario-twist every 3 days is not very realistic. I have scenario descriptions per 'month'. To populate a client record for an entire month, I could decide to break down the monthly scenario into smaller segments that fit the three-day prompt structure. I chose, however, to give the model the scenario in the first iteration and allowing it some creative freedom to build upon it, relying on the summaries to maintain continuity and build upon previous notes.

# %%
if VERBOSE:
    # Let's study the scenario
    test_client_id = test_client['client_id']
    df_client_scenarios = df_scenarios.loc[df_scenarios['client_id'] == test_client_id, ['journey', 'month']]  
    counter = 1
    for i, r in df_client_scenarios.iterrows():
        print(str(counter) + ' ' + r['journey'])
        counter = counter + 1
# Out:
# 1 Meneer Arjan Klerks wordt opgenomen in het verpleeghuis vanwege zijn FTD. Hij krijgt begeleiding bij ADL en gebruikt soms een wandelstok. Incidenteel vertoont hij dwangmatig gedrag en verbale agressie.
# 2 In de tweede maand is er geen significante verandering in zijn toestand. Meneer Arjan Klerks blijft minimale hulp nodig hebben bij ADL en vertoont af en toe dwangmatig gedrag.
# 3 Halverwege de derde maand ontwikkelt meneer Arjan Klerks een delier, wat resulteert in verwardheid en desoriëntatie. Zorgverleners passen hun benadering aan om hem te ondersteunen tijdens deze periode.
# 4 Na het delier herstelt meneer Arjan Klerks langzaam en keert terug naar zijn basisconditie. Zijn begeleiding en zorg blijven gericht op het omgaan met zijn FTD symptomen.
# 5 Aan het einde van de vijfde maand laat meneer Arjan Klerks geen significante verandering zien. Hij blijft ADL-ondersteuning en begeleiding nodig hebben, terwijl zijn zorgteam blijft omgaan met zijn dwangmatig gedrag en verbale agressie.

# %%
# Template for generating care notes 
PT_get_notes = PromptTemplate(
    template="""Jouw taak als AI is om zorgrapportages te schrijven van een fictieve client die verblijft op een psychogeriatrische afdeling van een verpleeghuis.
Hieronder staat:
- Het profiel van de client. 
- Een samenvatting van het beloop
- Het scenario van de rapportages die je moet schrijven

Voorbeeld rapportages:
- Dhr. zijn haar gewassen en zijn baard geschoren.
- Inco van mw, was verzadigd vanmorgen en bed was nat.
{examples}

PROFIEL:
{profile}

SAMENVATTING BELOOP TOT HEDEN:
{summary}

Gebruik een informele, menselijke stijl. Gebruik relatief eenvoudige taal en vermijd termen als 'cruciaal'.
Varieer met de zinsopbouw en stijl. Omschrijf de zorg, zonder het profiel letterlijk te herhalen. Vermijd het noemen van de naam.

Schrijf rapportages voor drie dagen. Per dag worden drie rapportages geschreven, dus er zijn 9 rapportages totaal.

SCENARIO voor de rapportages die je moet schrijven:
{scenario}

{format_instructions}
""",
    input_variables=["examples", "profile", "summary", "scenario"],
    partial_variables={"format_instructions": pyd_parser.get_format_instructions()},
)

if VERBOSE:
    P_get_notes = PT_get_notes.format(
        examples = sample_examples_as_string(example_library, num_items=3), 
        profile = profile_as_string(test_client),
        # Since we don't have a summary for the first round, we use the scenario for both summary and scenario
        summary = scenario_as_string(test_client, 1), 
        scenario = scenario_as_string(test_client, 1)
        )
    print(P_get_notes)
# Out:
# Jouw taak als AI is om zorgrapportages te schrijven van een fictieve client die verblijft op een psychogeriatrische afdeling van een verpleeghuis.
# Hieronder staat:
# - Het profiel van de client.
# - Een samenvatting van het beloop
# - Het scenario van de rapportages die je moet schrijven
#
# Voorbeeld rapportages:
# - Dhr. zijn haar gewassen en zijn baard geschoren.
# - Inco van mw, was verzadigd vanmorgen en bed was nat.
# - Dhr uit plotseling agressie richting medebewoner omdat hij ervan overtuigd is dat deze zijn geld heeft gestolen. Dhr schreeuwt en dreigt zonder duidelijke aankondiging. Dhr apart genomen voor rust en gesprek om de situatie uit te leggen en te kalmeren.
# - Overleg met collega's over aanpassingen in zorgplan dhr, meer fysiotherapie nodig
# - Dhr. vertoonde vanmiddag plotseling agressief gedrag richting het personeel en weigerde zich te laten verzorgen. Hij was onverstaanbaar aan het mompelen en balde zijn vuisten. Dhr. met behulp van collega's naar een rustige ruimte gebracht en daar gekalmeerd.\
#
# PROFIEL:
# Naam: Meneer Arjan Klerks
# Type Dementie: FTD
# Lichamelijke klachten: Geen significante lichamelijke klachten
# ADL: Heeft minimale hulp nodig bij ADL, alleen begeleiding bij douchen en aankleden.
# Mobiliteit: Licht onvast ter been, gebruikt soms een wandelstok
# Cognitie / gedrag: Vertonen van dwangmatig gedrag en soms verbale agressie. Kan ineens roepen of zingen.
#
# SAMENVATTING BELOOP TOT HEDEN:
# Meneer Arjan Klerks wordt opgenomen in het verpleeghuis vanwege zijn FTD. Hij krijgt begeleiding bij ADL en gebruikt soms een wandelstok. Incidenteel vertoont hij dwangmatig gedrag en verbale agressie.
#
# Gebruik een informele, menselijke stijl. Gebruik relatief eenvoudige taal en vermijd termen als 'cruciaal'.
# Varieer met de zinsopbouw en stijl. Omschrijf de zorg, zonder het profiel letterlijk te herhalen. Vermijd het noemen van de naam.
#
# Schrijf rapportages voor drie dagen. Per dag worden drie rapportages geschreven, dus er zijn 9 rapportages totaal.
#
# SCENARIO voor de rapportages die je moet schrijven:
# Meneer Arjan Klerks wordt opgenomen in het verpleeghuis vanwege zijn FTD. Hij krijgt begeleiding bij ADL en gebruikt soms een wandelstok. Incidenteel vertoont hij dwangmatig gedrag en verbale agressie.
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"properties": {"notes": {"title": "Notes", "type": "array", "items": {"$ref": "#/definitions/CareNote"}}}, "required": ["notes"], "definitions": {"CareNote": {"title": "CareNote", "type": "object", "properties": {"dag": {"title": "Dag", "description": "volgnummer dag", "type": "integer"}, "tijd": {"title": "Tijd", "description": "tijd van de rapportage (hh:mm)", "type": "string"}, "rapportage": {"title": "Rapportage", "description": "Inhoud van de rapportage. Een rapportage beschrijft over het algemeen \u00e9\u00e9n zorgaspect, soms meer", "type": "string"}}, "required": ["dag", "tijd", "rapportage"]}}}
# ```

# %% [markdown]
# Now we create a chain. The output of the chain is a structured list of (nine) care notes for a client, encapsulated in an object called CareNotes. This object contains an attribute named notes, which is a list of individual CareNote entries. Each CareNote entry includes three pieces of information(dag, tijd, rapportage)

# %%
# Create a chain of operations: prompt template -> model -> output parser
chain_get_notes = PT_get_notes | model | pyd_parser

if VERBOSE:
    test_notes = chain_get_notes.invoke({"examples": sampled_examples_as_string, 
                                         "profile": profile_as_string(test_client),
                                         "summary": scenario_as_string(test_client, month_no=1), 
                                         "scenario": scenario_as_string(test_client, month_no=1)})

    print('***The parsed result of model:')
    print(test_notes)

    print('\n***And these are the individual notes')
    for note in test_notes.notes:
        print(note)
# Out:
# ***The parsed result of model:
# notes=[CareNote(dag=1, tijd='08:00', rapportage='Meneer Klerks heeft vanmorgen zelfstandig ontbeten. Hij had wat moeite met het opendraaien van de pot jam, dus heb hem hierbij geholpen.'), CareNote(dag=1, tijd='12:30', rapportage='Tijdens de lunch werd meneer Klerks onrustig en begon hij te roepen. Heb hem rustig afgeleid door samen naar muziek te luisteren.'), CareNote(dag=1, tijd='17:00', rapportage='Meneer Klerks was erg vermoeid na de fysiotherapie, dus heb ik hem geholpen met naar bed gaan. Hij viel snel in slaap.'), CareNote(dag=2, tijd='09:15', rapportage='Tijdens de ochtendwandeling heeft meneer Klerks een paar keer omgedraaid en gezongen. Hij leek erg vrolijk en genoot van de buitenlucht.'), CareNote(dag=2, tijd='13:45', rapportage='Meneer Klerks was wat in de war na het middagdutje en begon te schreeuwen. Heb hem rustig naar de gemeenschappelijke ruimte gebracht en daar spelletjes met hem gespeeld.'), CareNote(dag=2, tijd='18:30', rapportage='Tijdens het avondeten wilde meneer Klerks per se zijn favoriete bord gebruiken, wat helaas in de vaatwasser stond. Heb hem geholpen met een ander bord kiezen.'), CareNote(dag=3, tijd='10:00', rapportage='Meneer Klerks was vanmorgen wat vergeetachtig en wist niet meer waar zijn kamer was. Heb hem begeleid naar zijn kamer en geholpen met oriëntatie.'), CareNote(dag=3, tijd='14:00', rapportage='Tijdens de knutselactiviteit begon meneer Klerks te spugen. Waarschijnlijk had hij zich verslikt. Heb dit gemeld aan de verpleegkundige en met meneer Klerks naar de dokter gegaan.'), CareNote(dag=3, tijd='19:30', rapportage='Meneer Klerks wilde vanavond niet naar bed en bleef maar door de gang lopen. Heb hem gezelschap gehouden totdat hij zelf moe werd en besloot te gaan rusten.')]
#
# ***And these are the individual notes
# dag=1 tijd='08:00' rapportage='Meneer Klerks heeft vanmorgen zelfstandig ontbeten. Hij had wat moeite met het opendraaien van de pot jam, dus heb hem hierbij geholpen.'
# dag=1 tijd='12:30' rapportage='Tijdens de lunch werd meneer Klerks onrustig en begon hij te roepen. Heb hem rustig afgeleid door samen naar muziek te luisteren.'
# dag=1 tijd='17:00' rapportage='Meneer Klerks was erg vermoeid na de fysiotherapie, dus heb ik hem geholpen met naar bed gaan. Hij viel snel in slaap.'
# dag=2 tijd='09:15' rapportage='Tijdens de ochtendwandeling heeft meneer Klerks een paar keer omgedraaid en gezongen. Hij leek erg vrolijk en genoot van de buitenlucht.'
# dag=2 tijd='13:45' rapportage='Meneer Klerks was wat in de war na het middagdutje en begon te schreeuwen. Heb hem rustig naar de gemeenschappelijke ruimte gebracht en daar spelletjes met hem gespeeld.'
# dag=2 tijd='18:30' rapportage='Tijdens het avondeten wilde meneer Klerks per se zijn favoriete bord gebruiken, wat helaas in de vaatwasser stond. Heb hem geholpen met een ander bord kiezen.'
# dag=3 tijd='10:00' rapportage='Meneer Klerks was vanmorgen wat vergeetachtig en wist niet meer waar zijn kamer was. Heb hem begeleid naar zijn kamer en geholpen met oriëntatie.'
# dag=3 tijd='14:00' rapportage='Tijdens de knutselactiviteit begon meneer Klerks te spugen. Waarschijnlijk had hij zich verslikt. Heb dit gemeld aan de verpleegkundige en met meneer Klerks naar de dokter gegaan.'
# dag=3 tijd='19:30' rapportage='Meneer Klerks wilde vanavond niet naar bed en bleef maar door de gang lopen. Heb hem gezelschap gehouden totdat hij zelf moe werd en besloot te gaan rusten.'

# %%
# Function formats the notes and returns them as a string for display
def notes_as_string(notes, simple_bulleted=True):
    note_strings = []
    for note in notes:
        if simple_bulleted:
            note_strings.append(f"- {note.rapportage}")
        else:
            note_strings.append(f"Dag {note.dag} ({note.tijd}): {note.rapportage}")
    return "\n".join(note_strings)

if VERBOSE:
    print(notes_as_string(test_notes.notes, simple_bulleted=False))
    test_notes_m1 = notes_as_string(test_notes.notes)
    print(SEP_LINE)
    print(test_notes_m1)
# Out:
# Dag 1 (08:00): Meneer Klerks heeft vanmorgen zelfstandig ontbeten. Hij had wat moeite met het opendraaien van de pot jam, dus heb hem hierbij geholpen.
# Dag 1 (12:30): Tijdens de lunch werd meneer Klerks onrustig en begon hij te roepen. Heb hem rustig afgeleid door samen naar muziek te luisteren.
# Dag 1 (17:00): Meneer Klerks was erg vermoeid na de fysiotherapie, dus heb ik hem geholpen met naar bed gaan. Hij viel snel in slaap.
# Dag 2 (09:15): Tijdens de ochtendwandeling heeft meneer Klerks een paar keer omgedraaid en gezongen. Hij leek erg vrolijk en genoot van de buitenlucht.
# Dag 2 (13:45): Meneer Klerks was wat in de war na het middagdutje en begon te schreeuwen. Heb hem rustig naar de gemeenschappelijke ruimte gebracht en daar spelletjes met hem gespeeld.
# Dag 2 (18:30): Tijdens het avondeten wilde meneer Klerks per se zijn favoriete bord gebruiken, wat helaas in de vaatwasser stond. Heb hem geholpen met een ander bord kiezen.
# Dag 3 (10:00): Meneer Klerks was vanmorgen wat vergeetachtig en wist niet meer waar zijn kamer was. Heb hem begeleid naar zijn kamer en geholpen met oriëntatie.
# Dag 3 (14:00): Tijdens de knutselactiviteit begon meneer Klerks te spugen. Waarschijnlijk had hij zich verslikt. Heb dit gemeld aan de verpleegkundige en met meneer Klerks naar de dokter gegaan.
# Dag 3 (19:30): Meneer Klerks wilde vanavond niet naar bed en bleef maar door de gang lopen. Heb hem gezelschap gehouden totdat hij zelf moe werd en besloot te gaan rusten.
# ----------------------------------------------------------------------------------------------------
# - Meneer Klerks heeft vanmorgen zelfstandig ontbeten. Hij had wat moeite met het opendraaien van de pot jam, dus heb hem hierbij geholpen.
# - Tijdens de lunch werd meneer Klerks onrustig en begon hij te roepen. Heb hem rustig afgeleid door samen naar muziek te luisteren.
# - Meneer Klerks was erg vermoeid na de fysiotherapie, dus heb ik hem geholpen met naar bed gaan. Hij viel snel in slaap.
# - Tijdens de ochtendwandeling heeft meneer Klerks een paar keer omgedraaid en gezongen. Hij leek erg vrolijk en genoot van de buitenlucht.
# - Meneer Klerks was wat in de war na het middagdutje en begon te schreeuwen. Heb hem rustig naar de gemeenschappelijke ruimte gebracht en daar spelletjes met hem gespeeld.
# - Tijdens het avondeten wilde meneer Klerks per se zijn favoriete bord gebruiken, wat helaas in de vaatwasser stond. Heb hem geholpen met een ander bord kiezen.
# - Meneer Klerks was vanmorgen wat vergeetachtig en wist niet meer waar zijn kamer was. Heb hem begeleid naar zijn kamer en geholpen met oriëntatie.
# - Tijdens de knutselactiviteit begon meneer Klerks te spugen. Waarschijnlijk had hij zich verslikt. Heb dit gemeld aan de verpleegkundige en met meneer Klerks naar de dokter gegaan.
# - Meneer Klerks wilde vanavond niet naar bed en bleef maar door de gang lopen. Heb hem gezelschap gehouden totdat hij zelf moe werd en besloot te gaan rusten.

# %%
# Seeing some iterations explicitly written out can make the flow of the process clearer, especially when tracking the sequence of actions and understanding the logic at each step. 
if VERBOSE:
    print('PROFILE')
    print(profile_as_string(test_client))
    print('\nSCENARIO: '+ scenario_as_string(test_client,month_no=1))
    print('\nNOTES')
    print(test_notes_m1)

    # Now have the model create a new summary 
    updated_summary = chain_memory.invoke({"profile": profile_as_string(test_client),
                                           # Initially, there is no summary
                                           "summary": scenario_as_string(test_client, month_no=1), 
                                           "new_notes": test_notes_m1})
    test_summary_m1 = updated_summary.content
    print('\nSUMMARY')
    pprint(test_summary_m1)

    # And again some notes
    test_notes = chain_get_notes.invoke({"examples": sample_examples_as_string(example_library, 3), 
                                         "profile": profile_as_string(test_client),
                                         "summary": test_summary_m1, 
                                         "scenario": "Bouw voort op de gegevens uit het Profiel en het Beloop"})

    test_notes_m2 = notes_as_string(test_notes.notes)
    print('\nSCENARIO: '+ "Bouw voort op de gegevens uit het Profiel en het Beloop")
    print('\nNOTES')
    print(test_notes_m2)

    # a new summary 
    updated_summary = chain_memory.invoke({"profile": profile_as_string(test_client),
                                           "summary": test_summary_m1, 
                                           "new_notes": test_notes_m2})
    test_summary_m2 = updated_summary.content
    print('\nSUMMARY')
    pprint(test_summary_m2)

    # And again some notes
    test_notes = chain_get_notes.invoke({"examples": sample_examples_as_string(example_library, 3), 
                                         "profile": profile_as_string(test_client),
                                         "summary": test_summary_m2, 
                                         "scenario": scenario_as_string(test_client, month_no=2)})

    test_notes_m3 = notes_as_string(test_notes.notes)
    print('\nSCENARIO: '+ scenario_as_string(test_client,month_no=2))
    print('\nNOTES')
    print(test_notes_m3)
# Out:
# PROFILE
# Naam: Meneer Arjan Klerks
# Type Dementie: FTD
# Lichamelijke klachten: Geen significante lichamelijke klachten
# ADL: Heeft minimale hulp nodig bij ADL, alleen begeleiding bij douchen en aankleden.
# Mobiliteit: Licht onvast ter been, gebruikt soms een wandelstok
# Cognitie / gedrag: Vertonen van dwangmatig gedrag en soms verbale agressie. Kan ineens roepen of zingen.
#
# SCENARIO: Meneer Arjan Klerks wordt opgenomen in het verpleeghuis vanwege zijn FTD. Hij krijgt begeleiding bij ADL en gebruikt soms een wandelstok. Incidenteel vertoont hij dwangmatig gedrag en verbale agressie.
#
# NOTES
# - Meneer Klerks heeft vanmorgen zelfstandig ontbeten. Hij had wat moeite met het opendraaien van de pot jam, dus heb hem hierbij geholpen.
# - Tijdens de lunch werd meneer Klerks onrustig en begon hij te roepen. Heb hem rustig afgeleid door samen naar muziek te luisteren.
# - Meneer Klerks was erg vermoeid na de fysiotherapie, dus heb ik hem geholpen met naar bed gaan. Hij viel snel in slaap.
# - Tijdens de ochtendwandeling heeft meneer Klerks een paar keer omgedraaid en gezongen. Hij leek erg vrolijk en genoot van de buitenlucht.
# - Meneer Klerks was wat in de war na het middagdutje en begon te schreeuwen. Heb hem rustig naar de gemeenschappelijke ruimte gebracht en daar spelletjes met hem gespeeld.
# - Tijdens het avondeten wilde meneer Klerks per se zijn favoriete bord gebruiken, wat helaas in de vaatwasser stond. Heb hem geholpen met een ander bord kiezen.
# - Meneer Klerks was vanmorgen wat vergeetachtig en wist niet meer waar zijn kamer was. Heb hem begeleid naar zijn kamer en geholpen met oriëntatie.
# - Tijdens de knutselactiviteit begon meneer Klerks te spugen. Waarschijnlijk had hij zich verslikt. Heb dit gemeld aan de verpleegkundige en met meneer Klerks naar de dokter gegaan.
# - Meneer Klerks wilde vanavond niet naar bed en bleef maar door de gang lopen. Heb hem gezelschap gehouden totdat hij zelf moe werd en besloot te gaan rusten.
#
# SUMMARY
# ('Meneer Arjan Klerks vertoont dwangmatig gedrag en verbale agressie vanwege '
#  'zijn FTD. Hij ontvangt begeleiding bij ADL en heeft hulp nodig bij '
#  'activiteiten zoals eten en naar bed gaan. Incidenten van onrust, verwarring '
#  'en fysiek ongemak doen zich voor, waarbij hij kan spugen of zich verslikt. '
#  'Er is sprake van geheugenproblemen en desoriëntatie, wat leidt tot '
#  'begeleiding naar zijn kamer en extra ondersteuning bij activiteiten. '
#  'Aandacht wordt besteed aan het verminderen van onrust en het stimuleren van '
#  'rust en ontspanning, zoals bijvoorbeeld door afleiding met activiteiten of '
#  'muziek.')
#
# SCENARIO: Bouw voort op de gegevens uit het Profiel en het Beloop
#
# NOTES
# - Meneer Klerks had vanmorgen moeite met opstaan en was wat verward. Hij heeft geholpen bij het aankleden en ontbijten.
# - Tijdens de lunch was meneer Klerks rusteloos en vroeg steeds om meer eten. Hij vertoonde dwangmatig gedrag en had moeite met stilzitten.
# - Meneer Klerks raakte geagiteerd tijdens het avondeten en had moeite met het herkennen van het eten op zijn bord. Hij is geholpen met eten en drinken.
# - Vanmorgen vertoonde meneer Klerks agressief gedrag toen hij werd geholpen met douchen. Hij schreeuwde en sloeg om zich heen. Er was extra ondersteuning nodig van het zorgteam.
# - Tijdens de middagactiviteit wilde meneer Klerks niet meedoen en bleef hij in zijn kamer. Hij was onrustig en liep heen en weer. Er is met hem gelopen in de gang om wat afleiding te bieden.
# - Meneer Klerks had moeite met in slaap vallen en belde herhaaldelijk op de bel om hulp. Hij kreeg extra aandacht en begeleiding om hem gerust te stellen.
# - Meneer Klerks was vanmorgen kalmer en meer coöperatief tijdens het ochtendritueel. Hij liet zich helpen met douchen en aankleden zonder veel weerstand.
# - Tijdens de koffiepauze vertoonde meneer Klerks roepgedrag en zong luidkeels. Hij had moeite met stilzitten en bleef bewegen in zijn stoel.
# - Meneer Klerks was rustiger tijdens het avondeten en at goed. Hij had minder last van dwangmatig gedrag en agressie. Hij ging op tijd naar bed en viel snel in slaap.
#
# SUMMARY
# ('Meneer Arjan Klerks vertoont nog steeds dwangmatig gedrag en verbale '
#  'agressie als gevolg van zijn FTD. Hij heeft moeite met opstaan en aankleden, '
#  'is onrustig tijdens maaltijden en vertoont agressief gedrag bij het douchen. '
#  'Tijdens activiteiten is hij vaak onrustig en zoekt hij afleiding. Echter, er '
#  'is ook sprake van verbetering waarbij hij kalmer en coöperatiever is tijdens '
#  'het ochtendritueel en rustiger tijdens het avondeten. Het is belangrijk om '
#  'hem te blijven ondersteunen en begeleiden bij zijn dagelijkse activiteiten.')
#
# SCENARIO: In de tweede maand is er geen significante verandering in zijn toestand. Meneer Arjan Klerks blijft minimale hulp nodig hebben bij ADL en vertoont af en toe dwangmatig gedrag.
#
# NOTES
# - Meneer geholpen met douchen en aankleden. Begon de dag rustig en coöperatief.
# - Tijdens de lunch onrustig en dwangmatig gedrag vertoond. Begeleiding geboden bij eten.
# - Meneer rustig gehouden met muziek en voorlezen. Geen tekenen van agressie vertoond.
# - Mobiliteitsoefeningen gedaan, wandeling buiten gemaakt met de wandelstok.
# - Tijdens het eten rustig en goed gegeten. Geen dwangmatig gedrag waargenomen.
# - Deelgenomen aan een groepsactiviteit. Meneer toonde interesse en meedoen met de groep.
# - Assistentie geboden bij het opstaan en aankleden. Langzamer op gang gekomen vandaag.
# - Tijdens de lunch onrustig gedrag vertoond en agressie bij het serveren van het eten.
# - Individuele activiteit gedaan. Meneer genoot van het samen knutselen en bleef rustig.

# %% [markdown]
# ### Fuctions to populate the client records

# %%
# Generate care notes for a client over a specified number of iterations and update the client summary
def generate_care_notes(summary_list, notes_list, profile_row, month_no, example_library, num_iterations=5, num_examples=3):  
    """
    Returns:
    - Updated list of summaries.
    - Updated list of care notes.
    """
    profile = profile_as_string(profile_row)
    scenario = scenario_as_string(profile_row, month_no=month_no)
    client_id = profile_row['client_id']
    summary = summary_list[-1]

    for i in range(num_iterations):
        iteration = i + 1
        try:
            print(f'Iteration {iteration}')
            if iteration > 1:
                # Update the scenario to let the model build upon the scenario
                scenario = "Bouw voort op de gegevens uit het Profiel en het Beloop."

            # Sample examples from the example library
            examples = sample_examples_as_string(example_library, num_examples)

            # Generate care notes using the model and the example library
            # There are frequent 'Invalid json output' errors. In that case, try again
            try:
                result_notes = chain_get_notes.invoke({
                    "examples": examples,
                    "profile": profile,
                    "summary": summary,
                    "scenario": scenario
                })
            except Exception as e:
                # Try once more in case of failure
                print(f"Error in iteration {iteration}, retrying: {e}")
                result_notes = chain_get_notes.invoke({
                    "examples": examples,
                    "profile": profile,
                    "summary": summary,
                    "scenario": scenario
                })
                print("Retry successful")

            # Update the summary based on the new care notes
            result_memory = chain_memory.invoke({
                 "profile": profile,
                 "summary": summary,
                 "new_notes": notes_as_string(result_notes.notes)
            })

            # Add generated notes to the notes list
            for note in result_notes.notes:
                notes_list.append({
                    "client_id": client_id,
                    "month": month_no,
                    "iteration": iteration,
                    "dag": note.dag,
                    "tijd": note.tijd,
                    "rapportage": note.rapportage,
                })

            # add_notes_to_list(result_notes.notes, notes_list, client_id, month_no, iteration)

            # Update the memory with new notes and generate a new summary
            summary = result_memory.content

            # Add the updated summary to the summary list 
            summary_list.append({
                "client_id": client_id,
                "month": month_no,
                "iteration": iteration,
                "summary": summary,
            })

        except Exception as e:
            print(f"Error in iteration {iteration}: {e}")
            continue

    return summary_list, notes_list

if VERBOSE:
    notes_list = []
    summary_list = []
    summary_list.append({
        "client_id": test_client['client_id'],
        "month": 0,
        "iteration": 0,
        "summary": scenario_as_string(test_client, month_no=1),
        })

    summary_list, notes_list = generate_care_notes(
        summary_list=summary_list, 
        notes_list=notes_list, 
        profile_row=test_client, 
        example_library=example_library,
        month_no=1,
        num_iterations=1,
        num_examples=3)
    
    for cs in summary_list:
        print(cs)
    print(100*'-')
    for n in notes_list:
        print(n)
# Out:
# Iteration 1
# {'client_id': 3, 'month': 0, 'iteration': 0, 'summary': 'Meneer Arjan Klerks wordt opgenomen in het verpleeghuis vanwege zijn FTD. Hij krijgt begeleiding bij ADL en gebruikt soms een wandelstok. Incidenteel vertoont hij dwangmatig gedrag en verbale agressie.'}
# {'client_id': 3, 'month': 1, 'iteration': 1, 'summary': 'Meneer Arjan Klerks vertoont nog steeds dwangmatig gedrag en verbale agressie, maar laat ook momenten van vrolijkheid zien. Hij heeft moeite met ADL taken zoals douchen en aankleden en vertoont rusteloos gedrag. Daarnaast lijkt hij in de war te zijn en vraagt regelmatig naar zijn overleden vrouw.'}
# ----------------------------------------------------------------------------------------------------
# {'client_id': 3, 'month': 1, 'iteration': 1, 'dag': 1, 'tijd': '09:00', 'rapportage': 'Meneer Arjan Klerks genoot van zijn ontbijt vanochtend en at alles op. Hij was vrolijk en maakte grapjes met het zorgpersoneel.'}
# {'client_id': 3, 'month': 1, 'iteration': 1, 'dag': 1, 'tijd': '13:00', 'rapportage': 'Meneer Arjan Klerks wilde niet meewerken met de douche, maar na een rustig gesprek ging hij toch akkoord. Hij toonde wat weerstand, maar liet het uiteindelijk toe.'}
# {'client_id': 3, 'month': 1, 'iteration': 1, 'dag': 1, 'tijd': '17:00', 'rapportage': 'Meneer Arjan Klerks was rusteloos en liep steeds de gang op en neer. Hij kon moeilijk stilzitten en had moeite met ontspannen. Na een kort wandelingetje kalmeerde hij wat.'}
# {'client_id': 3, 'month': 1, 'iteration': 1, 'dag': 2, 'tijd': '09:00', 'rapportage': 'Meneer Arjan Klerks had moeite met het aantrekken van zijn sokken. Hij leek gefrustreerd en geïrriteerd. Met wat geduld en hulp lukte het uiteindelijk wel.'}
# {'client_id': 3, 'month': 1, 'iteration': 1, 'dag': 2, 'tijd': '13:00', 'rapportage': 'Meneer Arjan Klerks bracht de middag door in de gemeenschappelijke ruimte. Hij raakte verstrikt in een tv-programma en leek het niet meer te volgen. Het leek hem te frustreren.'}
# {'client_id': 3, 'month': 1, 'iteration': 1, 'dag': 2, 'tijd': '17:00', 'rapportage': 'Meneer Arjan Klerks wilde niet aan tafel komen voor het avondeten en weigerde te eten. Hij vertoonde wat onrustig gedrag en leek in gedachten verzonken.'}
# {'client_id': 3, 'month': 1, 'iteration': 1, 'dag': 3, 'tijd': '09:00', 'rapportage': 'Meneer Arjan Klerks had een goede nachtrust en werd rustig wakker. Hij was vriendelijk tegen het zorgpersoneel en begon de dag met een glimlach.'}
# {'client_id': 3, 'month': 1, 'iteration': 1, 'dag': 3, 'tijd': '13:00', 'rapportage': 'Meneer Arjan Klerks wilde graag in de tuin zitten vanmiddag. Hij genoot van de buitenlucht en de frisse wind. Het leek hem te kalmeren en tot rust te brengen.'}
# {'client_id': 3, 'month': 1, 'iteration': 1, 'dag': 3, 'tijd': '17:00', 'rapportage': 'Meneer Arjan Klerks was wat in de war en vroeg steeds naar zijn vrouw die al jaren geleden is overleden. Het zorgpersoneel probeerde dit voorzichtig uit te leggen, maar het leek niet helemaal door te dringen.'}

# %% [markdown]
# Next, let's have a look at the generation of care notes and summaries for a single client. We need to process each client’s data individually. This involves iterating through their associated scenarios and generating relevant notes.

# %%
# Processe a single client to generate care notes and summaries.
def process_client(profile_row, df_scenarios, num_iterations=5, num_examples=3):
    all_notes_list = []
    all_summaries_list = []

    try:
        with get_openai_callback() as cb:
            print(f"Processing client: {profile_row['naam']}")

            summary_list = []
            notes_list = []

            client_id = profile_row['client_id']
            # As initial summary, we take the scenario of the first month
            summary_list.append({
                "client_id": profile_row['client_id'],
                "month": 0,
                "iteration": 0,
                "summary": scenario_as_string(profile_row=profile_row, month_no=1),
                })

            # Select the scenario rows for the client
            df_client_scenarios = df_scenarios.loc[df_scenarios['client_id'] == client_id, ['journey', 'month']]  

            num_months = len(df_client_scenarios)

            month_no = 1    
            for i, month_scenario in df_client_scenarios.iterrows():  
                scenario = scenario_as_string(profile_row, month_no)
                example_library = create_example_library(profile_row, scenario)

                print(f'Generating notes for month: {month_no} of {num_months} for client {client_id}')
                summary_list, notes_list = generate_care_notes(
                    summary_list=summary_list,
                    notes_list=notes_list, 
                    profile_row=profile_row,
                    month_no=month_no,
                    example_library=example_library,
                    num_iterations=num_iterations,
                    num_examples=num_examples,
                    )
                month_no += 1

            # Add client_id to notes and summaries
            for note in notes_list:
                note['client_id'] = client_id
            for summary in summary_list:
                all_summaries_list.append({'client_id': client_id, 'summary': summary, 'month': month_no})  

            all_notes_list.extend(notes_list)
            print(cb)

    except Exception as e:
        print(f"Error processing client {profile_row['naam']}: {e}")

    return all_notes_list, all_summaries_list

if VERBOSE:
    notes_list, summaries_list = process_client(profile_row=test_client, df_scenarios=df_scenarios, num_iterations=2, num_examples=3)
    for cs in summaries_list:
        print(cs)

    for n in notes_list:
        print(n)

# %%
# Iterate through all clients, processes each one, and saves the generated notes and summaries to CSV files.
def main(df_profiles, df_scenarios):
    all_notes_list = []
    all_summaries_list = []

    for idx, row in df_profiles.iterrows():
        try:
            notes, summaries = process_client(row, df_scenarios)
            all_notes_list.extend(notes)
            all_summaries_list.extend(summaries)

            df_notes = pd.DataFrame(all_notes_list)
            df_summaries = pd.DataFrame(all_summaries_list)

            # save after each client to prevent having to start over in case of an error
            df_notes.to_csv(PATH_NOTES, index=False)
            df_summaries.to_csv(PATH_SUMMARIES, index=False)
        except Exception as e:
            print(f"Error processing client: {e}")

# %% [markdown]
# ## Main workflow

# %%
if __name__ == "__main__":
    main(df_profiles=df_profiles,
         df_scenarios=df_scenarios)
# Out:
# Processing client: Meneer Henk Timmers
# Generating notes for month: 1 of 4 for client 1
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 4 for client 1
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Error in iteration 4, retrying: Failed to parse CareNotes from completion {"notes": [{"dag": 1, "tijd": "09:00", "rapportage": "Meneer heeft vanochtend geholpen met aankleden en wassen. Baard geschoren en tanden gepoetst zonder problemen. Hij toonde wat verwarring bij het kiezen van kleding, maar kon uiteindelijk zelfstandig beslissingen nemen."}, {"dag": 1, "tijd": "13:30", "rapportage": "Tijdens de lunch had meneer last van lichte duizeligheid en vermoeidheid. Hij at redelijk goed en dronk voldoende water. Na de maaltijd even laten rusten in zijn stoel, waarna hij zich beter voelde."}, {"dag": 1, "tijd": "17:00", "rapportage": "Meneer had na het avondeten moeite met het herkennen van het bed als slaapplek. Hij was angstig en onrustig, waarop we hem geruststelden en begeleidden naar bed. Na wat extra aandacht kon hij toch rustig in slaap vallen."}, {"dag": 2, "tijd": "10:30", "rapportage": "Vanochtend tijdens de fysiotherapie sessie was meneer wat onrustig en vergeetachtig. Hij vergat de juiste oefeningen te doen, maar met wat extra begeleiding lukte het uiteindelijk wel. Wel is het duidelijk dat zijn cognitieve achteruitgang doorzet."}, {"tijd": "14:00", "rapportage": "Meneer had na de lunch last van incontinentie en voelde zich erg gegeneerd. We hebben hem rustig geholpen met verschonen en hebben zijn zelfvertrouwen weer op proberen te bouwen."}, {"tijd": "18:30", "rapportage": "Tijdens het diner was meneer erg alert en at hij met smaak. Hij nam kleine hapjes en at zijn bord vrijwel leeg. Aan het einde dronk hij zelfs het volgende glas water op. Goede eetlust!"}, {"dag": 3, "tijd": "08:00", "rapportage": "Meneer had vanochtend last van hoge bloeddruk en voelde zich duizelig. Hij weigerde in eerste instantie hulp, maar na een paar minuten besloot hij toch rust te nemen in zijn stoel en wat extra vocht te drinken. Na korte tijd voelde hij zich weer beter."}, {"tijd": "12:30", "rapportage": "Tijdens de lunch was meneer wat verward en kon hij moeilijk zijn eten herkennen. Met wat extra uitleg over de maaltijd en begeleiding bij het eten, lukte het hem toch om voldoende voedsel binnen te krijgen. Zijn stemming klaarde duidelijk op na het eten."}, {"tijd": "16:00", "rapportage": "Meneer vertoonde vanmiddag tekenen van angst en onrust. Hij was niet goed in staat om duidelijk te maken waar het vandaan kwam. We hebben hem extra aandacht gegeven en rustig met hem gepraat, waarna hij langzaam weer kalmeerde."}]}. Got: 4 validation errors for CareNotes
# notes -> 4 -> dag
#   field required (type=value_error.missing)
# notes -> 5 -> dag
#   field required (type=value_error.missing)
# notes -> 7 -> dag
#   field required (type=value_error.missing)
# notes -> 8 -> dag
#   field required (type=value_error.missing)
# Iteration 5
# Generating notes for month: 3 of 4 for client 1
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 4 for client 1
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 59265
# 	Prompt Tokens: 41775
# 	Completion Tokens: 17490
# Successful Requests: 45
# Total Cost (USD): $0.04712250000000001
# Processing client: Mevrouw Lize Verbruggen
# Generating notes for month: 1 of 5 for client 2
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 5 for client 2
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 5 for client 2
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 5 for client 2
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 5 for client 2
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 73194
# 	Prompt Tokens: 51262
# 	Completion Tokens: 21932
# Successful Requests: 55
# Total Cost (USD): $0.058529
# Processing client: Meneer Arjan Klerks
# Generating notes for month: 1 of 5 for client 3
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 5 for client 3
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 5 for client 3
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 5 for client 3
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 5 for client 3
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 73755
# 	Prompt Tokens: 51630
# 	Completion Tokens: 22125
# Successful Requests: 55
# Total Cost (USD): $0.05900250000000002
# Processing client: Mevrouw Mia Janssen
# Generating notes for month: 1 of 7 for client 4
# Iteration 1
# Iteration 2
# Iteration 3
# Error in iteration 3, retrying: Invalid json output: {
#     "notes": [
#         {
#             "dag": 1,
#             "tijd": "08:30",
#             "rapportage": "Heeft vanochtend moeite met opstaan uit bed vanwege spierzwakte. Extra hulp geboden bij het aankleden."
#         },
#         {
#             "dag": 1,
#             "tijd": "13:00",
#             "rapportage": "Tijdens de lunch had ze problemen met het vasthouden van bestek door de tremoren. Geholpen met eten."
#         },
#         {
#             "dag": 1,
#             "tijd": "16:45",
#             "rapportage": "Ervaart hallucinaties tijdens therapie. Constante geruststelling gegeven om haar te kalmeren."
#         },
#         {
#             "dag": 2,
#             "tijd": "09:45",
#             "rapportage": "Heeft vanochtend extra ondersteuning nodig bij mobiliteitsoefeningen vanwege evenwichtsproblemen."
#         },
#         {
#             "dag": 2,
#             "tijd": "11:30",
#             "rapportage": "Tijdens het wandelen ondersteuning geboden bij vermoeidheid en spierzwakte."
#         },
#         {
#             "dag": 2,
#             "tijd": "15:00",
#             "rapportage": "Vertoont onrustig gedrag. Nabijheid geboden en afleiding gezocht voor haar welzijn."
#         },
#         {
#             "dag": 3,
#             "tijd": "10:15",
#             "rapportage": "Bij het ontbijt extra hulp geboden bij het vasthouden van een kopje vanwege tremoren in haar handen."
#         },
#         {
#             "dag": 3,
#             "tijd": "12:45",
#             "rapportage": "Moeite met lopen vandaag. Constante begeleiding geboden om valincidenten te voorkomen."
#         },
#         {
#             "dag": 3
#             "tijd": "17:30",
#             "rapportage": "Tijdens avondeten rustig en wat stijf. Voor comfort gezorgd en extra ondersteuning geboden bij het eten."
#         }
#     ]
# }
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 7 for client 4
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 7 for client 4
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 7 for client 4
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 7 for client 4
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 6 of 7 for client 4
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 7 of 7 for client 4
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 102092
# 	Prompt Tokens: 71732
# 	Completion Tokens: 30360
# Successful Requests: 78
# Total Cost (USD): $0.08140599999999998
# Processing client: Meneer Theo Boterenbrood
# Generating notes for month: 1 of 1 for client 5
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 14462
# 	Prompt Tokens: 10336
# 	Completion Tokens: 4126
# Successful Requests: 11
# Total Cost (USD): $0.011357
# Processing client: Mevrouw Sophie Brandsma
# Generating notes for month: 1 of 6 for client 6
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 6 for client 6
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 6 for client 6
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 6 for client 6
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 6 for client 6
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 6 of 6 for client 6
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 87233
# 	Prompt Tokens: 61049
# 	Completion Tokens: 26184
# Successful Requests: 66
# Total Cost (USD): $0.0698005
# Processing client: Meneer Karel Dijkhuizen
# Generating notes for month: 1 of 7 for client 7
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 7 for client 7
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 7 for client 7
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 7 for client 7
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 7 for client 7
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 6 of 7 for client 7
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 7 of 7 for client 7
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 100903
# 	Prompt Tokens: 71259
# 	Completion Tokens: 29644
# Successful Requests: 77
# Total Cost (USD): $0.08009550000000001
# Processing client: Mevrouw Eva Kuipers
# Generating notes for month: 1 of 1 for client 8
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 13645
# 	Prompt Tokens: 9709
# 	Completion Tokens: 3936
# Successful Requests: 11
# Total Cost (USD): $0.010758500000000002
# Processing client: Mevrouw Eva van der Zwaan
# Generating notes for month: 1 of 6 for client 9
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 6 for client 9
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 6 for client 9
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 6 for client 9
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 6 for client 9
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 6 of 6 for client 9
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 83319
# 	Prompt Tokens: 58730
# 	Completion Tokens: 24589
# Successful Requests: 66
# Total Cost (USD): $0.0662485
# Processing client: Meneer Lucas de Waard
# Generating notes for month: 1 of 8 for client 10
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 8 for client 10
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 8 for client 10
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 8 for client 10
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 8 for client 10
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 6 of 8 for client 10
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 7 of 8 for client 10
# Iteration 1
# Error in iteration 1, retrying: Invalid json output: {
#     "notes": [
#         {
#             "dag": 1,
#             "tijd": "08:30",
#             "rapportage": "Meneer heeft vanochtend zijn persoonlijke verzorging ontvangen en is geholpen bij het ontbijt. Hij leek wat somber en teruggetrokken.",
#         },
#         {
#             "dag": 1,
#             "tijd": "13:45",
#             "rapportage": "Tijdens de lunch had meneer wat moeite met het vasthouden van zijn bestek. Na enige hulp heeft hij zijn maaltijd zelfstandig kunnen afmaken.",
#         },
#         {
#             "dag": 1,
#             "tijd": "18:20",
#             "rapportage": "Meneer heeft vanavond extra begeleiding gekregen bij het verplaatsen van bed naar stoel, vanwege zijn mobiliteitsproblemen. Hij leek vermoeid en rusteloos.",
#         },
#         {
#             "dag": 2,
#             "tijd": "09:00",
#             "rapportage": "Meneer had vanochtend last van een lage bloedsuikerspiegel, waardoor hij wat verward en prikkelbaar was. Extra controle en aanpassing van zijn dieet is nodig.",
#         },
#         {
#             "dag": 2,
#             "tijd": "14:10",
#             "rapportage": "Tijdens de middagactiviteit leek meneer opgewekter en meer betrokken bij de groepsactiviteit. Hij genoot van de muziektherapie en interactie met anderen.",
#         },
#         {
#             "dag": 2,
#             "tijd": "19:30",
#             "rapportage": "Meneer had vanavond extra fysieke ondersteuning nodig bij het naar bed gaan, vanwege zijn vermoeidheid en onrustige gedrag. Hij viel uiteindelijk rustig in slaap.",
#         },
#         {
#             "dag": 3,
#             "tijd": "10:15",
#             "rapportage": "Vandaag heeft meneer deelgenomen aan de ochtendoefeningen en leek hij energieker dan normaal. Hij was actiever en beter in staat om instructies op te volgen.",
#         },
#         {
#             "dag": 3,
#             "tijd": "15:45",
#             "rapportage": "Tijdens het middagsnackmoment had meneer moeite met het eten vanwege zijn slikproblemen. Extra aandacht en geduld waren nodig om hem te helpen met eten en drinken.",
#         },
#         {
#             "dag": 3,
#             "tijd": "20:00",
#             "rapportage": "Vanavond leek meneer rustiger en meer ontspannen dan gebruikelijk. Hij genoot van een rustige avond en kon met minimale begeleiding naar bed gaan.",
#         }
#     ]
# }
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 8 of 8 for client 10
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 116446
# 	Prompt Tokens: 80952
# 	Completion Tokens: 35494
# Successful Requests: 89
# Total Cost (USD): $0.09371700000000002
# Processing client: Mevrouw Sofie Kleiberg
# Generating notes for month: 1 of 9 for client 11
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 9 for client 11
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 9 for client 11
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Error in iteration 4, retrying: Invalid json output: {
#   "notes": [
#     {
#       "dag": 1,
#       "tijd": "08:30",
#       "rapportage": "Cli\u00ebnt ondersteund bij het wassen en aankleden. Slikproblemen leidden tot langzame voortgang. Extra aandacht besteed aan voeding en hydratatie."
#     },
#     {
#       "dag": 1,
#       "tijd": "12:15",
#       "rapportage": "Tijdens lunch moeite met slikken, regelmatig herinnerd om langzaam te eten en goed te kauwen. Toenemende onrust waargenomen, rustgevende benadering toegepast."
#     },
#     {
#       "dag": 1,
#       "tijd": "15:45",
#       "rapportage": "Cli\u00ebnt gevallen tijdens poging om op te staan uit stoel. Geen letsel, maar valgevaar benadrukt. Later moeite met ori\u00ebntatie, extra begeleiding geboden."
#     },
#     {
#       "dag": 2,
#       "tijd": "09:00",
#       "rapportage": "Hallucinaties waargenomen bij cli\u00ebnt tijdens ochtendzorg. Rustig benaderd en afleiding geboden. Advies ingewonnen bij psycholoog voor vervolgstappen."
#     },
#     {
#       "dag": 2,
#       "tijd": "13:30",
#       "rapportage": "Na middagrust moeite met mobiliteit en evenwicht. Confidence-building oefeningen uitgevoerd met fysiotherapeut. Extra voorzichtigheid geboden bij transitie van zitten naar staan."
#     },
#     {
#       "dag": 2,
#       "tijd": "17:00",
#       "rapportage": "Cli\u00ebnt onrustig en angstig voor het avondeten. Gerustgesteld en ondersteund bij maaltijd. Medicatieopties besproken met arts voor verbetering van slaapkwaliteit."
#     },
#     {
#       "dag": 3,
#       "tijd": "10:45",
#       "rapportage": "Slikproblemen verergerd tijdens ontbijt, langere tijd nodig om kleine portie te consumeren. Voedingsassistent geconsulteerd voor alternatieven en aanpassingen."
#     },
#     {
#       "dag": 3,
#       "tijd": "14:20",
#       "rapportage": "Verbetering van valpreventiebespreking met verpleegteam. Extra alertheid vereist bij beweging en ondersteuning. Familie ge\00efnformeerd over recente valincidenten."
#     },
#     {
#       "dag": 3,
#       "tijd": "16:50",
#       "rapportage": "Moeite met dagelijkse activiteiten door toenemende verwardheid. Geduldige begeleiding geboden. Medicatie evaluatie gepland om bijwerkingen te controleren."
#     }
#   ]
# }
# Iteration 5
# Generating notes for month: 4 of 9 for client 11
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 9 for client 11
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 6 of 9 for client 11
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 7 of 9 for client 11
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 8 of 9 for client 11
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 9 of 9 for client 11
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 127149
# 	Prompt Tokens: 89550
# 	Completion Tokens: 37599
# Successful Requests: 100
# Total Cost (USD): $0.10117350000000003
# Processing client: Meneer Bas Groenendaal
# Generating notes for month: 1 of 4 for client 12
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 4 for client 12
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 4 for client 12
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Error in iteration 5, retrying: Failed to parse CareNotes from completion {"notes": [{"Dag": 1, "Tijd": "08:00", "Rapportage": "Meneer heeft vanochtend zijn medicatie geweigerd en is agressief geworden tijdens de ADL-zorg. Overleg met de psycholoog voor begeleiding in omgaan met agressief gedrag."}, {"Dag": 1, "Tijd": "14:30", "Rapportage": "Meneer is vanmiddag onrustig en heeft diverse hallucinaties gemeld. Verpleegkundige heeft extra monitoring ingezet en rapporteert gedrag aan behandeld arts."}, {"Dag": 1, "Tijd": "20:00", "Rapportage": "Meneer heeft vanavond een valincident gehad in zijn kamer. Geen lichamelijk letsel, maar extra observatie ingezet om valrisico te monitoren."}, {"Dag": 2, "Tijd": "08:00", "Rapportage": "Meneer heeft ochtendzorg gehad en is somber en verward. Familie gebeld om hen op de hoogte te brengen van veranderingen in gedrag."}, {"Dag": 2, "Tijd": "14:30", "Rapportage": "Meneer heeft vanmiddag meegewerkt aan de huidinspectie en decubituspreventiemaatregelen. Speciale cr\u00e8me aangebracht op risicoplekken en educatie gegeven over huidverzorging."}, {"Dag": 2, "Tijd": "20:00", "Rapportage": "Meneer heeft vanavond genoten van de avondactiviteiten en was rustig en ontspannen. Geen bijzonderheden waargenomen tijdens de avondronde."}, {"Dag": 3, "Tijd": "08:00", "Rapportage": "Meneer heeft vanochtend last van vermoeidheid en heeft lichte koorts. Arts geconsulteerd voor controle van zijn gezondheidstoestand."}, {"Dag": 3, "Tijd": "14:30", "Rapportage": "Meneer is vanmiddag aangehaald en gerustgesteld tijdens een verwarde periode. Verpleging heeft extra aandacht besteed aan zijn emotionele welzijn."}, {"Dag": 3, "Tijd": "20:00", "Rapportage": "Meneer had vanavond een epileptische aanval. Verpleegkundige heeft medicatie toegediend en extra observatie ingezet voor de nacht."}]}. Got: 27 validation errors for CareNotes
# notes -> 0 -> dag
#   field required (type=value_error.missing)
# notes -> 0 -> tijd
#   field required (type=value_error.missing)
# notes -> 0 -> rapportage
#   field required (type=value_error.missing)
# notes -> 1 -> dag
#   field required (type=value_error.missing)
# notes -> 1 -> tijd
#   field required (type=value_error.missing)
# notes -> 1 -> rapportage
#   field required (type=value_error.missing)
# notes -> 2 -> dag
#   field required (type=value_error.missing)
# notes -> 2 -> tijd
#   field required (type=value_error.missing)
# notes -> 2 -> rapportage
#   field required (type=value_error.missing)
# notes -> 3 -> dag
#   field required (type=value_error.missing)
# notes -> 3 -> tijd
#   field required (type=value_error.missing)
# notes -> 3 -> rapportage
#   field required (type=value_error.missing)
# notes -> 4 -> dag
#   field required (type=value_error.missing)
# notes -> 4 -> tijd
#   field required (type=value_error.missing)
# notes -> 4 -> rapportage
#   field required (type=value_error.missing)
# notes -> 5 -> dag
#   field required (type=value_error.missing)
# notes -> 5 -> tijd
#   field required (type=value_error.missing)
# notes -> 5 -> rapportage
#   field required (type=value_error.missing)
# notes -> 6 -> dag
#   field required (type=value_error.missing)
# notes -> 6 -> tijd
#   field required (type=value_error.missing)
# notes -> 6 -> rapportage
#   field required (type=value_error.missing)
# notes -> 7 -> dag
#   field required (type=value_error.missing)
# notes -> 7 -> tijd
#   field required (type=value_error.missing)
# notes -> 7 -> rapportage
#   field required (type=value_error.missing)
# notes -> 8 -> dag
#   field required (type=value_error.missing)
# notes -> 8 -> tijd
#   field required (type=value_error.missing)
# notes -> 8 -> rapportage
#   field required (type=value_error.missing)
# Generating notes for month: 4 of 4 for client 12
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 58394
# 	Prompt Tokens: 41314
# 	Completion Tokens: 17080
# Successful Requests: 45
# Total Cost (USD): $0.046277
# Processing client: Mevrouw Anja Vos
# Generating notes for month: 1 of 10 for client 13
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 10 for client 13
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 10 for client 13
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 10 for client 13
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 10 for client 13
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 6 of 10 for client 13
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 7 of 10 for client 13
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 8 of 10 for client 13
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 9 of 10 for client 13
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 10 of 10 for client 13
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 142769
# 	Prompt Tokens: 100807
# 	Completion Tokens: 41962
# Successful Requests: 110
# Total Cost (USD): $0.11334650000000002
# Processing client: Meneer Guus de Jong
# Generating notes for month: 1 of 4 for client 14
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Error in iteration 4, retrying: Invalid json output: {
# 	"notes": [
# 		{
# 			"dag": 1,
# 			"tijd": "09:30",
# 			"rapportage": "Bewoner heeft vanochtend onder begeleiding gedoucht en aangekleed. Hij leek wat angstig tijdens het douchen, maar kon met geruststellende woorden tot rust komen.",
# 		},
# 		{
# 			"dag": 1,
# 			"tijd": "12:00",
# 			"rapportage": "Tijdens de lunch weigerde bewoner zelfstandig te eten. Verzorgende heeft hem geholpen met het nuttigen van zijn maaltijd. Bewoner leek apathisch en keek voor zich uit met een lege blik."
# 		},
# 		{
# 			"dag": 1,
# 			"tijd": "15:45",
# 			"rapportage": "Bewoner vertoonde tekenen van hallucinaties en reageerde angstig op 'zien' van denkbeeldige dieren. Verpleegkundige heeft bewoner gerustgesteld en afleiding geboden met muziektherapie."
# 		},
# 		{
# 			"dag": 2,
# 			"tijd": "10:15",
# 			"rapportage": "Bewoner had vanmorgen weer last van hallucinaties. Verpleegkundige heeft arts ingelicht voor eventuele aanpassing van medicatie. Bewoner leek wat vermoeid en verward."
# 		},
# 		{
# 			"dag": 2,
# 			"tijd": "13:30",
# 			"rapportage": "Na de lunch heeft bewoner samen met medebewoners en activiteitenbegeleider buiten een wandeling gemaakt. Bewoner genoot zichtbaar van de frisse lucht en het zonnetje."
# 		},
# 		{
# 			"dag": 2,
# 			"tijd": "16:00",
# 			"rapportage": "Bewoner viel vanmiddag met rollator, gelukkig zonder ernstige verwondingen. Verpleegkundige heeft bewoner geholpen en gecheckt op eventuele pijnklachten. Bewoner was geschrokken maar leek verder oké."
# 		},
# 		{
# 			"dag": 3,
# 			"tijd": "08:45",
# 			"rapportage": "Bewoner had vanochtend moeite met opstaan en was duizelig. Verpleegkundige heeft bewoner geholpen om rustig te gaan zitten en hem van extra ondersteuning voorzien. Bewoner was daarna wat meer alert."
# 		},
# 		{
# 			"dag": 3,
# 			"tijd": "11:00",
# 			"rapportage": "Tijdens de koffiepauze vertoonde bewoner apathisch gedrag en weigerde hij te drinken. Verpleegkundige heeft hem met geduld en aanmoediging geholpen om toch wat te drinken. Bewoner leek daarna wat meer betrokken."
# 		},
# 		{
# 			"dag": 3,
# 			"tijd": "14:20",
# 			"rapportage": "In de middag heeft bewoner deelgenomen aan een geheugentrainingssessie. Ondanks enkele verwarrende momenten, was bewoner enthousiast en betrokken bij de activiteit. Begeleiding heeft bewoner extra complimenten gegeven."
# 		}
# 	]
# }
# Iteration 5
# Generating notes for month: 2 of 4 for client 14
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 4 for client 14
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 4 for client 14
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 58852
# 	Prompt Tokens: 41027
# 	Completion Tokens: 17825
# Successful Requests: 45
# Total Cost (USD): $0.04725099999999999
# Processing client: Mevrouw Louise Nieuweboer
# Generating notes for month: 1 of 5 for client 15
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 5 for client 15
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 5 for client 15
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 5 for client 15
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 5 for client 15
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 72385
# 	Prompt Tokens: 50850
# 	Completion Tokens: 21535
# Successful Requests: 55
# Total Cost (USD): $0.057727499999999994
# Processing client: Meneer Kaj van Riet
# Generating notes for month: 1 of 8 for client 16
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 8 for client 16
# Iteration 1
# Iteration 2
# Iteration 3
# Error in iteration 3, retrying: Failed to parse CareNotes from completion {"notes": [{"dag": 1, "tijd": "08:00", "rapportage": "Cli\u00ebnt was vanmorgen erg onrustig en klaagde veel. Extra kalmerende maatregelen ingezet om hem te helpen kalmeren."}, {"dag": 1, "tijd": "12:30", "rapportage": "Inco van cli\u00ebnt was verzadigd vanmiddag en bed was nat. Extra aandacht besteed aan het verschonen en verzorgen van cli\u00ebnt."}, {"dag": 1, "tijd": "17:45", "rapportage": "Cli\u00ebnt had moeite met eten en slikken tijdens het avondeten. Persoonlijke begeleiding geboden en aangepaste zorg verleend."}, {"dag": 2, "tijd": "08:15", "rapportage": "Cli\u00ebnt was erg verward en angstig bij het opstaan. Troost en geruststelling geboden om hem te helpen kalmeren."}, {"dag": 2, "tijd": "13:00", "rapportage": "Meneer protesteerde bij het gebruik van de rolstoel en wilde liever zelf lopen. Activiteitenplan aangepast om hier rekening mee te houden."}, {"day": 2, "time": "18:20", "report": "Cli\u00ebnt vertoonde onrustig gedrag en riep om hulp tijdens de avondzorg. Na geruststelling viel hij snel in slaap."}, {"day": 3, "time": "09:10", "report": "Cli\u00ebnt had een benauwde ochtend vanwege COPD. Extra zuurstof en rustgevende maatregelen ingezet om zijn ademhaling te verlichten."}, {"day": 3, "time": "14:45", "report": "Cli\u00ebnt ervoer valangst tijdens het transfermoment. Veiligheidshulpmiddelen gebruikt om valincidenten te voorkomen."}, {"day": 3, "time": "19:30", "report": "Cli\u00ebnt was erg verward en dacht dat hij nog op zijn werk was. Probeerp poging te doen om hem uit te leggen waar hij zich bevindt."}]}. Got: 12 validation errors for CareNotes
# notes -> 5 -> dag
#   field required (type=value_error.missing)
# notes -> 5 -> tijd
#   field required (type=value_error.missing)
# notes -> 5 -> rapportage
#   field required (type=value_error.missing)
# notes -> 6 -> dag
#   field required (type=value_error.missing)
# notes -> 6 -> tijd
#   field required (type=value_error.missing)
# notes -> 6 -> rapportage
#   field required (type=value_error.missing)
# notes -> 7 -> dag
#   field required (type=value_error.missing)
# notes -> 7 -> tijd
#   field required (type=value_error.missing)
# notes -> 7 -> rapportage
#   field required (type=value_error.missing)
# notes -> 8 -> dag
#   field required (type=value_error.missing)
# notes -> 8 -> tijd
#   field required (type=value_error.missing)
# notes -> 8 -> rapportage
#   field required (type=value_error.missing)
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 8 for client 16
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 8 for client 16
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 8 for client 16
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 6 of 8 for client 16
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 7 of 8 for client 16
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 8 of 8 for client 16
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 119160
# 	Prompt Tokens: 83724
# 	Completion Tokens: 35436
# Successful Requests: 89
# Total Cost (USD): $0.095016
# Processing client: Mevrouw Clara de Vries
# Generating notes for month: 1 of 5 for client 17
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 5 for client 17
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 5 for client 17
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 5 for client 17
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 5 for client 17
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 67351
# 	Prompt Tokens: 47994
# 	Completion Tokens: 19357
# Successful Requests: 55
# Total Cost (USD): $0.05303250000000002
# Processing client: Meneer Jan Bos
# Generating notes for month: 1 of 4 for client 18
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 4 for client 18
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 4 for client 18
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 4 for client 18
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 54330
# 	Prompt Tokens: 38548
# 	Completion Tokens: 15782
# Successful Requests: 44
# Total Cost (USD): $0.042947
# Processing client: Mevrouw Bep Janssen
# Generating notes for month: 1 of 4 for client 19
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 4 for client 19
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 4 for client 19
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 4 for client 19
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 55980
# 	Prompt Tokens: 39459
# 	Completion Tokens: 16521
# Successful Requests: 44
# Total Cost (USD): $0.044511
# Processing client: Meneer Wim van Dijk
# Generating notes for month: 1 of 4 for client 20
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 4 for client 20
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 4 for client 20
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 4 for client 20
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 61128
# 	Prompt Tokens: 42445
# 	Completion Tokens: 18683
# Successful Requests: 44
# Total Cost (USD): $0.049247000000000006
# Processing client: Mevrouw Annie Vermeulen
# Generating notes for month: 1 of 8 for client 21
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 8 for client 21
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 8 for client 21
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 8 for client 21
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 8 for client 21
# Iteration 1
# Iteration 2
# Error in iteration 2, retrying: Invalid json output: {
#   "notes": [
#     {
#       "dag": 1,
#       "tijd": "08:30",
#       "rapportage": "Bewoner geholpen met wassen en aankleden. Geen verzet, maar weinig reactie op de omgeving.",
#     },
#     {
#       "dag": 1,
#       "tijd": "13:45",
#       "rapportage": "Tijdens de lunch weinig eetlust. Bewoner lijkt verward en weigert hulp bij eten.",
#     },
#     {
#       "dag": 1,
#       "tijd": "18:20",
#       "rapportage": "Incontinentieproblemen gehad bij de transfer van bed naar rolstoel. Extra hygiënische zorg toegepast.",
#     },
#     {
#       "dag": 2,
#       "tijd": "09:10",
#       "rapportage": "Overleg met verpleegkundige over aanpassingen in zorgplan voor betere mobiliteit. Toekomstige valincidenten voorkomen.",
#     },
#     {
#       "dag": 2,
#       "tijd": "15:30",
#       "rapportage": "Bewoner onrustig en roept regelmatig om haar overleden partner. Geruststellende woorden helpen om haar te kalmeren.",
#     },
#     {
#       "dag": 2,
#       "tijd": "20:00",
#       "rapportage": "Aanhoudende duizeligheidsklachten bij bewoner. Advies ingewonnen bij de huisarts voor verdere beoordeling.",
#     },
#     {
#       "dag": 3,
#       "tijd": "07:45",
#       "rapportage": "Bewoner van bed naar stoel getransfereerd. Duidelijke aanwijzingen en langzame bewegingen helpen bij het voorkomen van incontinentie.",
#     },
#     {
#       "dag": 3,
#       "tijd": "12:15",
#       "rapportage": "Mw lijkt meer apathisch vandaag. Weinig interactie met zorgverleners, maar geen tekenen van agressie.",
#     },
#     {
#       "dag": 3,
#       "tijd": "16:40",
#       "rapportage": "Overleg met fysiotherapeut over oefeningen ter verbetering van mobiliteit en evenwicht. Bewoner lijkt gemotiveerd om deel te nemen.",
#     }
#   ]
# }
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 6 of 8 for client 21
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 7 of 8 for client 21
# Iteration 1
# Iteration 2
# Iteration 3
# Error in iteration 3, retrying: Failed to parse CareNotes from completion {"notes": [{"Dag": 1, "Tijd": "08:30", "Rapportage": "Mw. heeft vanmorgen goed ontbeten en haar medicatie ingenomen. Haar kleding is verschoond en ze lijkt rustig te zijn in haar kamer."}, {"Dag": 1, "Tijd": "13:45", "Rapportage": "Mw. heeft tijdens de lunch weinig gegeten en gedronken. Er wordt extra aandacht besteed aan het stimuleren van haar vochtinname en voeding."}, {"Dag": 1, "Tijd": "18:00", "Rapportage": "Mw. is vanavond vroeg naar bed gegaan en lijkt vermoeid te zijn. Er wordt extra rust en comfort geboden om haar te ondersteunen."}, {"Dag": 2, "Tijd": "09:15", "Rapportage": "Mw. is vanmorgen vroeg wakker en lijkt wat onrustig te zijn. Er wordt extra aandacht besteed aan afleiding en stimulatie van activiteiten."}, {"Dag": 2, "Tijd": "14:30", "Rapportage": "Mw. heeft vanmiddag goed gegeten en gedronken. Er wordt gelet op haar mobiliteit om obstipatie te voorkomen en haar osteoporose te ondersteunen."}, {"Dag": 2, "Tijd": "19:45", "Rapportage": "Mw. heeft vanavond genoten van een bezoek van familie. Er is extra aandacht besteed aan haar mondverzorging en comfort na het bezoek."}, {"Dag": 3, "Tijd": "10:00", "Rapportage": "Mw. is vanmorgen rustig en lijkt te genieten van de zon in de tuin. Haar incontinentiezorg is bijgewerkt en ze is comfortabel."}, {"Dag": 3, "Tijd": "15:20", "Rapportage": "Mw. heeft deze middag wat geslapen en lijkt vermoeid te zijn. Er wordt extra rust en ontspanning geboden om haar te ondersteunen."}, {"Dag": 3, "Tijd": "20:00", "Rapportage": "Mw. is vanavond laat actief in de woonkamer met de medebewoners. Er wordt aandacht besteed aan haar mobiliteit en stimulatie van sociale interactie."}]}. Got: 27 validation errors for CareNotes
# notes -> 0 -> dag
#   field required (type=value_error.missing)
# notes -> 0 -> tijd
#   field required (type=value_error.missing)
# notes -> 0 -> rapportage
#   field required (type=value_error.missing)
# notes -> 1 -> dag
#   field required (type=value_error.missing)
# notes -> 1 -> tijd
#   field required (type=value_error.missing)
# notes -> 1 -> rapportage
#   field required (type=value_error.missing)
# notes -> 2 -> dag
#   field required (type=value_error.missing)
# notes -> 2 -> tijd
#   field required (type=value_error.missing)
# notes -> 2 -> rapportage
#   field required (type=value_error.missing)
# notes -> 3 -> dag
#   field required (type=value_error.missing)
# notes -> 3 -> tijd
#   field required (type=value_error.missing)
# notes -> 3 -> rapportage
#   field required (type=value_error.missing)
# notes -> 4 -> dag
#   field required (type=value_error.missing)
# notes -> 4 -> tijd
#   field required (type=value_error.missing)
# notes -> 4 -> rapportage
#   field required (type=value_error.missing)
# notes -> 5 -> dag
#   field required (type=value_error.missing)
# notes -> 5 -> tijd
#   field required (type=value_error.missing)
# notes -> 5 -> rapportage
#   field required (type=value_error.missing)
# notes -> 6 -> dag
#   field required (type=value_error.missing)
# notes -> 6 -> tijd
#   field required (type=value_error.missing)
# notes -> 6 -> rapportage
#   field required (type=value_error.missing)
# notes -> 7 -> dag
#   field required (type=value_error.missing)
# notes -> 7 -> tijd
#   field required (type=value_error.missing)
# notes -> 7 -> rapportage
#   field required (type=value_error.missing)
# notes -> 8 -> dag
#   field required (type=value_error.missing)
# notes -> 8 -> tijd
#   field required (type=value_error.missing)
# notes -> 8 -> rapportage
#   field required (type=value_error.missing)
# Iteration 4
# Iteration 5
# Generating notes for month: 8 of 8 for client 21
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 114530
# 	Prompt Tokens: 79540
# 	Completion Tokens: 34990
# Successful Requests: 90
# Total Cost (USD): $0.09225500000000002
# Processing client: Meneer Karel de Jong
# Generating notes for month: 1 of 5 for client 22
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 5 for client 22
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 5 for client 22
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 5 for client 22
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 5 for client 22
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 72875
# 	Prompt Tokens: 50990
# 	Completion Tokens: 21885
# Successful Requests: 55
# Total Cost (USD): $0.058322500000000006
# Processing client: Mevrouw Lisa Hendriks
# Generating notes for month: 1 of 5 for client 23
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 5 for client 23
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 5 for client 23
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 5 for client 23
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 5 for client 23
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 69430
# 	Prompt Tokens: 49099
# 	Completion Tokens: 20331
# Successful Requests: 55
# Total Cost (USD): $0.055046000000000005
# Processing client: Meneer Theo Smits
# Generating notes for month: 1 of 8 for client 24
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 2 of 8 for client 24
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 3 of 8 for client 24
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 4 of 8 for client 24
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 5 of 8 for client 24
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 6 of 8 for client 24
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 7 of 8 for client 24
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Generating notes for month: 8 of 8 for client 24
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Tokens Used: 117037
# 	Prompt Tokens: 81657
# 	Completion Tokens: 35380
# Successful Requests: 88
# Total Cost (USD): $0.09389849999999997

# %%
def update_dag_counter(df):
    """
    This function updates the 'dag' column in df such that it maintains a running counter per client and per month.
    The counter starts at 1 and increments by 1 each time the 'dag' value changes. The counter resets to 1 for each new client and month.
    """
    # Add a column to shift 'dag' values by one row within each group of client_id and month
    df['dag_shift'] = df.groupby(['client_id', 'month'])['dag'].shift(1)
    # Create a column indicating if 'dag' has changed compared to the previous row
    df['dag_changed'] = (df['dag'] != df['dag_shift']).astype(int)
    # Create a column indicating the start of a new group (client_id and month)
    df['group_changed'] = df.groupby(['client_id', 'month']).cumcount() == 0
    
    # Update 'group_changed' to be False if 'dag_shift' is NaN
    df['group_changed'] = df['group_changed'] & df['dag_shift'].notna()
    # Create the counter ('teller') by cumulatively summing 'dag_changed' within each group and adding 'group_changed'
    df['dag'] = df.groupby(['client_id', 'month'])['dag_changed'].cumsum() + df['group_changed']
    
    # Remove the temporary columns used for calculations
    df.drop(columns=['dag_shift', 'dag_changed', 'group_changed'], inplace=True)
    
    return df

# %%
dfn = pd.read_csv(PATH_NOTES)
dfn = update_dag_counter(dfn)
dfn.to_csv(PATH_NOTES, index=False)
