# %% [markdown]
# <a href="https://colab.research.google.com/github/ekrombouts/GenCareAI/blob/main/scripts/data_generation/110_GenerateClientProfilesWithLangchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GenCare AI: Generating client profiles
#
# **Author:** Eva Rombouts
# **Date:** 2024-06-01
# **Version:** 1.0
#
# ### Description
# This script generates synthetic healthcare data for NLP experiments.
# It utilizes OpenAI to create an anonymized dataset that mimics real-world client records of nursing care homes for use in machine learning and data analysis.
#
# ### Setup
# - Set the [OpenAI API key](https://platform.openai.com/docs/quickstart?context=python) in the environment or configuration file.
# - Mount Google Drive for file operations if running in Colab.

# %%
# Imports needed for Google Colab
# !pip install -q langchain langchain_core langchain_openai

# %%
from typing import List

from langchain.output_parsers import PydanticOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_openai import ChatOpenAI

import pandas as pd
import os

# %%
# Mount google drive for storing the .csv file
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Get the OpenAI API key.
from google.colab import userdata
OPENAI_API_KEY =userdata.get('GCI_OPENAI_API_KEY')

# %% [markdown]
# When using the OpenAI model with the same inputs, it tends to produce similar outputs each time (a phenomenon known as determinism). This is a limitation in this scenario where we aim for diversity and variability in generated results. Even with the temperature set to 1 to increase variability, the model frequently selected Lewy Body dementia as the dementia type and diabetes, arthritis, and hypertension as conditions.
#
# To enhance diversity, I implemented several strategies:
# - Switching to the gpt-4o model
# - Creating multiple profiles in each query
# - Adjusting the temperature setting to 1 to promote more varied responses.

# %%
# The ward name will be used in the filename. Practical when performing multiple
# experiments
WARD_NAME = 'Horizon'
# Per query eight profiles are generated. The query is run NUM_WINGS times, so
# when NUM_WINGS is set to 3 the total number of client profiles generated is 24.
NUM_WINGS = 3
# GPT-4o yields better, more diverse results and handles instructions better.
MODEL_PROFILES = 'gpt-4o-2024-05-13'
TEMP = 1.0

DATA_DIR = '/content/drive/My Drive/Colab Notebooks/GenCareAI/data'
FN_PROFILES = os.path.join(DATA_DIR, f'gcai_client_profiles_{WARD_NAME}.csv')

# %%
# Initialize OpenAI model
model = ChatOpenAI(api_key=OPENAI_API_KEY, temperature=TEMP, model=MODEL_PROFILES)

# %%
# Define a Pydantic model to structure the client profile data
class ClientProfile(BaseModel):
    naam: str = Field(description="naam van de client (Meneer/Mevrouw Voornaam Achternaam, wees creatief in de namen)")
    type_dementie: str = Field(description="type dementie (Alzheimer, gemengde dementie, vasculaire dementie, lewy body dementie, parkinsondementie, FTD: varieer, de kans op Alzheimer, gemengde en vasculaire dementie is het grootst)")
    somatiek: str = Field(description="lichamelijke klachten")
    # biografie: str = Field(description="een korte beschrijving van karakter en relevante biografische gegevens (vermijd stereotypen in beroep en achtergrond)")
    adl: str = Field(description="beschrijf welke ADL hulp de cliënt nodig heeft")
    mobiliteit: str = Field(description="beschrijf de mobiliteit (bv rolstoelafhankelijk, gebruik rollator, valgevaar)")
    gedrag: str = Field(description="beschrijf voor de zorg relevante aspecten van cognitie en probleemgedrag. Varieer met de ernst van het probleemgedrag van rustige cliënten, gemiddeld onrustige cliënten tot cliënten die fors apathisch, onrustig, angstig, geagiteerd of zelfs agressief kunnen zijn")

# Define a Pydantic model to hold multiple client profiles
class ClientProfiles(BaseModel):
    clients: List[ClientProfile]

# %%
# Query to generate multiple client profiles
client_query = """
Schrijf acht profielen van cliënten die zijn opgenomen op een psychogeriatrische afdeling van het verpleeghuis. Hier wonen mensen met een gevorderde dementie met een hoge zorgzwaarte.
Zorg dat de profielen erg van elkaar verschillen.
"""

# %%
# Set up a parser to handle the output and inject instructions into the prompt template
parser = PydanticOutputParser(pydantic_object=ClientProfiles)

# %%
# Define the prompt template with placeholders for query and format instructions
prompt = PromptTemplate(
    template="Beantwoord de query.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

# Check the prompt template
print(prompt)
# Out:
# input_variables=['query'] partial_variables={'format_instructions': 'The output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"properties": {"clients": {"title": "Clients", "type": "array", "items": {"$ref": "#/definitions/ClientProfile"}}}, "required": ["clients"], "definitions": {"ClientProfile": {"title": "ClientProfile", "type": "object", "properties": {"naam": {"title": "Naam", "description": "naam van de client (Meneer/Mevrouw Voornaam Achternaam, wees creatief in de namen)", "type": "string"}, "type_dementie": {"title": "Type Dementie", "description": "type dementie (Alzheimer, gemengde dementie, vasculaire dementie, lewy body dementie, parkinsondementie, FTD: varieer, de kans op Alzheimer, gemengde en vasculaire dementie is het grootst)", "type": "string"}, "somatiek": {"title": "Somatiek", "description": "lichamelijke klachten", "type": "string"}, "adl": {"title": "Adl", "description": "beschrijf welke ADL hulp de cli\\u00ebnt nodig heeft", "type": "string"}, "mobiliteit": {"title": "Mobiliteit", "description": "beschrijf de mobiliteit (bv rolstoelafhankelijk, gebruik rollator, valgevaar)", "type": "string"}, "gedrag": {"title": "Gedrag", "description": "beschrijf voor de zorg relevante aspecten van cognitie en probleemgedrag. Varieer met de ernst van het probleemgedrag van rustige cli\\u00ebnten, gemiddeld onrustige cli\\u00ebnten tot cli\\u00ebnten die fors apathisch, onrustig, angstig, geagiteerd of zelfs agressief kunnen zijn", "type": "string"}}, "required": ["naam", "type_dementie", "somatiek", "adl", "mobiliteit", "gedrag"]}}}\n```'} template='Beantwoord de query.\n{format_instructions}\n{query}\n'

# %%
# Create a chain of operations: prompt template -> model -> output parser
chain = prompt | model | parser

# %%
def load_or_generate_data(file_path):
    """Load data from file if exists, otherwise generate new data."""
    try:
        if os.path.exists(file_path):
            df = pd.read_csv(file_path)
            print("Data file found. Data loaded successfully.")
        else:
            print("Data file not found. Generating new data...")

            all_data = []
            for _ in range(NUM_WINGS):
                result = chain.invoke({"query": client_query})
                if result is None or not hasattr(result, 'clients'):
                    raise ValueError("No valid response received from the model.")
                data = [client.dict() for client in result.clients]
                all_data.extend(data)
            df = pd.DataFrame(all_data)
            df.to_csv(file_path, index=False)
            print("Data generated and saved successfully.")
        return df

    except Exception as e:
        print(f"An error occurred: {e}")
        raise

# %%
# Main execution
df = load_or_generate_data(FN_PROFILES)
# Out:
# Data file not found. Generating new data...
# Data generated and saved successfully.

# %%
df.head(24)
# Out:
#                          naam                   type_dementie  \
# 0         Meneer Jan de Vries                       Alzheimer
# 1   Mevrouw Anna van den Berg              Lewy body dementie
# 2        Meneer Pieter Jansen             Vasculaire dementie
# 3        Mevrouw Maria de Wit  Frontotemporale dementie (FTD)
# 4             Meneer Kees Kok               Gemengde dementie
# 5       Mevrouw Lisa de Groot               Parkinsondementie
# 6          Meneer Theo Peters                       Alzheimer
# 7         Mevrouw Clara Smits             Vasculaire dementie
# 8         Meneer Jan de Vries                       Alzheimer
# 9         Mevrouw Anna Jansen             Vasculaire dementie
# 10      Meneer Pieter de Boer              Lewy body dementie
# 11     Mevrouw Elsie van Dijk               Parkinsondementie
# 12   Meneer Kees van den Berg                             FTD
# 13    Mevrouw Maria Verhoeven               Gemengde dementie
# 14       Meneer Thomas Bakker             Vasculaire dementie
# 15      Mevrouw Johanna Klein                       Alzheimer
# 16          Meneer Jan Jansen                       Alzheimer
# 17     Mevrouw Truus De Vries              Lewy body dementie
# 18         Meneer Henk Bakker               Gemengde dementie
# 19        Mevrouw Anja Koster             Vasculaire dementie
# 20      Meneer Willem de Boer                             FTD
# 21       Mevrouw Carla Visser                       Alzheimer
# 22      Meneer Klaas de Groot               Parkinsondementie
# 23    Mevrouw Linda Vermeulen               Gemengde dementie
#
#                                              somatiek  \
# 0             Beperkt gehoor, artrose in beide knieën
# 1                      Beperkt zicht, diabetes type 2
# 2                      Hartaandoening, hoge bloeddruk
# 3                     Osteoporose, moeite met slikken
# 4                                  COPD, slechthorend
# 5   Tremoren door Parkinson, moeite met fijne moto...
# 6                     Chronische rugpijn, hypertensie
# 7                            Hartproblemen, nierfalen
# 8                      Chronische rugpijn en artritis
# 9                          Diabetes en hoge bloeddruk
# 10                                      Hartproblemen
# 11             Tremoren en spierzwakte door Parkinson
# 12            Geen significante lichamelijke klachten
# 13                                      COPD en astma
# 14               Slechtziend en lijdend aan nierfalen
# 15                            Lijdend aan osteoporose
# 16                            Diabetes, gehoorverlies
# 17                           Parkinson, incontinentie
# 18                           Hoge bloeddruk, artritis
# 19    Hartproblemen, beperkte mobiliteit in linkerarm
# 20                                  COPD, slechtziend
# 21                  Gehoorverlies, chronische rugpijn
# 22                       Slaapproblemen, spasticiteit
# 23                             Hartfalen, osteoporose
#
#                                                   adl  \
# 0       Hulp bij aankleden en wassen, eet zelfstandig
# 1   Volledige hulp nodig bij eten en drinken, inco...
# 2         Hulp nodig bij douchen en aan- en uitkleden
# 3          Hulp nodig bij alle dagelijkse handelingen
# 4     Heeft hulp nodig bij het wassen en toiletbezoek
# 5   Hulp bij eten en drinken, hulp bij persoonlijk...
# 6   Heeft hulp nodig bij aan- en uitkleden, kan zi...
# 7      Volledige hulp nodig bij voeding en toiletgang
# 8   Heeft hulp nodig bij het aankleden en in bad gaan
# 9   Heeft hulp nodig bij het klaarmaken van maalti...
# 10  Heeft begeleiding nodig bij dagelijkse activit...
# 11        Hulp nodig bij alle dagelijkse activiteiten
# 12  Redelijk zelfstandig, heeft soms hulp nodig bi...
# 13  Heeft hulp nodig bij het gebruik van inhalator...
# 14  Heeft volledige hulp nodig bij alle activiteit...
# 15  Heeft hulp nodig bij het opstaan, wassen en na...
# 16           Hulp nodig bij aankleden, wassen en eten
# 17   Volledige hulp nodig bij persoonlijke verzorging
# 18                Hulp nodig bij douchen en aankleden
# 19               Hulp nodig bij toiletgang en douchen
# 20                     Hulp nodig bij eten en drinken
# 21                Hulp nodig bij persoonlijke hygiëne
# 22                   Hulp nodig bij aankleden en eten
# 23  Volledige hulp nodig bij alle dagelijkse activ...
#
#                                            mobiliteit  \
# 0       Maakt gebruik van een rollator, valgevaarlijk
# 1     Rolstoelafhankelijk, kan niet zelfstandig lopen
# 2   Heeft een looprek nodig, langzaam en voorzicht...
# 3                      Valgevaarlijk, soms bedlegerig
# 4   Heeft een rollator nodig, kortademig bij inspa...
# 5               Rolstoelafhankelijk, trage mobiliteit
# 6              Valgevaarlijk, gebruikt een wandelstok
# 7               Bedlegerig, heeft fysiotherapie nodig
# 8                 Gebruik van een rollator, valgevaar
# 9                                 Rolstoelafhankelijk
# 10      Loopt zelf, maar heeft soms moeite met balans
# 11                  Volledige rolstoelafhankelijkheid
# 12        Licht valgevaar, gebruikt geen hulpmiddelen
# 13       Invalide door COPD, afhankelijk van rolstoel
# 14                       Volledig rolstoelafhankelijk
# 15              Gebruikt een rollator, hoog valgevaar
# 16                  Loopt met een rollator, valgevaar
# 17                                Rolstoelafhankelijk
# 18                Loopt zelfstandig, lichte valgevaar
# 19                       Gebruikt rollator, valgevaar
# 20                         Loopt onstabiel, valgevaar
# 21                                Rolstoelafhankelijk
# 22                      Loopt met rollator, valgevaar
# 23     Rolstoelafhankelijk, lift nodig voor transfers
#
#                                                gedrag
# 0      Redelijk rustig, soms verward en vergeetachtig
# 1   Vaak angstig en hallucinaties, af en toe agres...
# 2   Vertoont rustige momenten afgewisseld met peri...
# 3   Sterk apathisch, soms plotseling boos of gefru...
# 4   Vaak onrustig, begrijpt instructies slecht, ka...
# 5   Rustig en volgzaam, maar snel verward en verge...
# 6   Apathisch, kan soms van streek raken, neigt af...
# 7   Vaak angstig en onrustig, moeite om gebeurteni...
# 8       Rustig, maar kan verward zijn in de avonduren
# 9             Apathisch en vertoont weinig initiatief
# 10  Ernstige nachtmerries en hallucinaties, gemidd...
# 11  Rustig gedurende de dag, maar angstig en onrus...
# 12      Fors apathisch, soms agressieve uitbarstingen
# 13  Overdag rustig, maar vaak verward, vooral in d...
# 14     Gemiddeld onrustig, vaak angstig en geagiteerd
# 15  Agressieve uitbarstingen wanneer verward, maar...
# 16                Rustig, vergeetachtig, soms verward
# 17                 Fors apathisch, soms hallucinaties
# 18      Gemiddeld onrustig, kan soms agressief worden
# 19                 Stemmingswisselingen, soms angstig
# 20          Zeer onrustig, kan verbaal agressief zijn
# 21                Rustig, veel behoefte aan structuur
# 22                 Kan zeer angstig en verward worden
# 23                Zeer rustig, sociaal teruggetrokken
